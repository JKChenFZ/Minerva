# %% [markdown]
# ### Colab Setup

# %%
# !unzip /content/pretrained_models.zip

# %%
% cd /content/pretrained_models/tensorflow
# Out:
# /content/pretrained_models/tensorflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
savePath = "/content/drive/MyDrive/MinervaModel/"

# %% [markdown]
# ### Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib
# from tensorboard.plugins.hparams import api as hp
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report
# from tensorflow.python.keras import backend as K

# %% [markdown]
# ### Parameters

# %%
batch_size = 64
img_height = 150
img_width = 150
data_dir = "../data/"

# %% [markdown]
# ### Get Training Data

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir+"train/",
  labels="inferred",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 26795 files belonging to 2 classes.
# Using 21436 files for training.

# %% [markdown]
# ### Get Validation Data

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir+"train/",
  labels="inferred",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 26795 files belonging to 2 classes.
# Using 5359 files for validation.

# %% [markdown]
# ### Get Testing Data

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir+"test/",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7536 files belonging to 2 classes.

# %%
class_names = train_ds.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    im = images[i].numpy().astype("uint8")
    plt.imshow(im)
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Preprocessing

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Load Pretrained Model

# %%
def getBaseModel():
  base_model = keras.applications.Xception(
      weights='imagenet',  # Load weights pre-trained on ImageNet.
      input_shape=(150, 150, 3),
      include_top=False)  # Do not include the ImageNet classifier at the top.
  return base_model

# %% [markdown]
# ### Setting Up Model

# %%
def setupModel(baseModel, name):
  inputs = keras.Input(shape=(img_height, img_width, 3))

  x = baseModel(inputs, training=False)
  # Convert features of shape `base_model.output_shape[1:]` to vectors
  x = keras.layers.GlobalAveragePooling2D()(x)
  # A Dense classifier with a single unit (binary classification)
  # outputs = keras.layers.Dense(1)(x)
  outputs = keras.activations.sigmoid(keras.layers.Dense(1)(x))
  model = keras.Model(inputs, outputs)
  return model

# %% [markdown]
# ### Freezed Training

# %%
def freezedTraining(model, baseModel, optimizers, numEpochs, loss):
    # freeze the base layer weights
    baseModel.trainable = False
    model.compile(optimizer=optimizers,
                loss=loss,
                metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Recall(), keras.metrics.Precision()])
    print(model.summary())
    earlyStopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='min')
    history = model.fit(train_ds, epochs=numEpochs, validation_data=val_ds, callbacks=[earlyStopping])
    return history

# %% [markdown]
# ### Unfreeze Training

# %%
def unfreezedTraining(model, baseModel, optimizer, numEpochs, modelName, loss):
      # Unfreeze the base model
      baseModel.trainable = True
      # with K.name_scope(model.optimizer.__class__.__name__):
      #       for i, var in enumerate(model.optimizer.weights):
      #           name = 'variable{}'.format(i)
      #           model.optimizer.weights[i] = tf.Variable(var, name=name)
      earlyStopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, mode='min')
      # mcp_save = ModelCheckpoint(modelName, save_best_only=True, verbose=1, monitor='val_loss', mode='min')
      reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1, mode='min')

      model.compile(optimizer=optimizer,  # Very low learning rate
                    loss=loss,
                    metrics=[keras.metrics.BinaryAccuracy(), keras.metrics.Recall(), keras.metrics.Precision()])
      print(model.summary())

      history = model.fit(train_ds, epochs=numEpochs, validation_data=val_ds, callbacks=[earlyStopping, reduce_lr_loss])
      return history

# %% [markdown]
# ### Hyperparameter Optimization

# %%
fineTuneLR = 1e-5
lossFunctions = [(keras.losses.BinaryCrossentropy(), 'BinaryCrossEntropy')]
optimizers = [
                (keras.optimizers.Adam(), keras.optimizers.Adam(learning_rate=fineTuneLR), 'Adams'), 
                (keras.optimizers.SGD(), keras.optimizers.SGD(learning_rate=fineTuneLR), 'SGD'),
                (keras.optimizers.RMSprop(), keras.optimizers.RMSprop(learning_rate=fineTuneLR), 'RMSprop')
             ]
modelName = 'ImageNetXception'

# %%
resultsForGraph =  {}
for lossFunc, lossName in lossFunctions:
    for freezeOptimizer, unfreezeOptimizer, optimizerName in optimizers:
        acc = []
        val_acc = []
        loss = []
        val_loss = []
        print("####################Loss: " + lossName + " Optimizer: " + optimizerName + "####################")
        print("--------------------Get Pretrained Model--------------------")
        base_model = getBaseModel()
        print("--------------------Setup Model--------------------")
        model = setupModel(base_model, modelName+lossName+optimizerName)

        print("--------------------Freezed Training--------------------")
        history = freezedTraining(model, base_model, freezeOptimizer,  100, lossFunc)
        acc = history.history['binary_accuracy']
        val_acc = history.history['val_binary_accuracy']

        loss = history.history['loss']
        val_loss = history.history['val_loss']

        print("--------------------Fine Tunning--------------------")
        history_fine = unfreezedTraining(model, base_model, unfreezeOptimizer, 100, modelName+lossName+optimizerName+'.h5', lossFunc)
        acc += history_fine.history['binary_accuracy']
        val_acc += history_fine.history['val_binary_accuracy']

        loss += history_fine.history['loss']
        val_loss += history_fine.history['val_loss']

        print("--------------------Testing Result--------------------")
        results = model.evaluate(test_ds, batch_size=batch_size)
        resultsForGraph[modelName+lossName+optimizerName] = (acc, loss, val_acc, val_loss, results)
        print("--------------------Saving Model--------------------")
        print("saving model to: "+savePath+modelName+lossName+optimizerName) 
        model.save(savePath+modelName+lossName+optimizerName, save_format='h5')
# Out:
# ####################Loss: BinaryCrossEntropy Optimizer: Adams####################
# --------------------Get Pretrained Model--------------------
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 6s 0us/step
# --------------------Setup Model--------------------
# --------------------Freezed Training--------------------
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid (TensorF [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 2,049
# Non-trainable params: 20,861,480
# _________________________________________________________________
# None
# Epoch 1/100
# 335/335 [==============================] - 25s 74ms/step - loss: 1.2757 - binary_accuracy: 0.5357 - recall: 0.5242 - precision: 0.5339 - val_loss: 0.9032 - val_binary_accuracy: 0.5734 - val_recall: 0.5355 - val_precision: 0.5907
# Epoch 2/100
# 335/335 [==============================] - 31s 94ms/step - loss: 0.9258 - binary_accuracy: 0.5689 - recall: 0.5633 - precision: 0.5670 - val_loss: 0.8660 - val_binary_accuracy: 0.5861 - val_recall: 0.4353 - val_precision: 0.6389
# Epoch 3/100
# 335/335 [==============================] - 34s 100ms/step - loss: 0.8443 - binary_accuracy: 0.5824 - recall: 0.5784 - precision: 0.5805 - val_loss: 1.1547 - val_binary_accuracy: 0.5309 - val_recall: 0.1542 - val_precision: 0.6785
# Epoch 4/100
# 335/335 [==============================] - 34s 100ms/step - loss: 0.8611 - binary_accuracy: 0.5864 - recall: 0.5833 - precision: 0.5843 - val_loss: 0.8066 - val_binary_accuracy: 0.6063 - val_recall: 0.5534 - val_precision: 0.6303
# Epoch 5/100
# 335/335 [==============================] - 33s 99ms/step - loss: 0.7717 - binary_accuracy: 0.5991 - recall: 0.5952 - precision: 0.5973 - val_loss: 0.8804 - val_binary_accuracy: 0.5684 - val_recall: 0.8589 - val_precision: 0.5495
# Epoch 6/100
# 335/335 [==============================] - 33s 99ms/step - loss: 0.7762 - binary_accuracy: 0.6046 - recall: 0.6032 - precision: 0.6024 - val_loss: 0.7562 - val_binary_accuracy: 0.6128 - val_recall: 0.5168 - val_precision: 0.6525
# Epoch 7/100
# 335/335 [==============================] - 33s 99ms/step - loss: 0.7508 - binary_accuracy: 0.6116 - recall: 0.6082 - precision: 0.6099 - val_loss: 1.1033 - val_binary_accuracy: 0.5260 - val_recall: 0.1162 - val_precision: 0.7227
# Epoch 8/100
# 335/335 [==============================] - 33s 98ms/step - loss: 0.7767 - binary_accuracy: 0.6074 - recall: 0.6045 - precision: 0.6055 - val_loss: 0.8213 - val_binary_accuracy: 0.5936 - val_recall: 0.3984 - val_precision: 0.6720
# Epoch 9/100
# 335/335 [==============================] - 33s 97ms/step - loss: 0.7464 - binary_accuracy: 0.6170 - recall: 0.6102 - precision: 0.6161 - val_loss: 0.9023 - val_binary_accuracy: 0.5725 - val_recall: 0.2548 - val_precision: 0.7345
# Epoch 00009: early stopping
# --------------------Fine Tunning--------------------
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid (TensorF [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 20,809,001
# Non-trainable params: 54,528
# _________________________________________________________________
# None
# Epoch 1/100
#   2/335 [..............................] - ETA: 39s - loss: 0.9805 - binary_accuracy: 0.5859 - recall_1: 0.6094 - precision_1: 0.5821WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0742s vs `on_train_batch_end` time: 0.1612s). Check your callbacks.
# 335/335 [==============================] - 84s 252ms/step - loss: 0.6712 - binary_accuracy: 0.6314 - recall_1: 0.6281 - precision_1: 0.6298 - val_loss: 0.7142 - val_binary_accuracy: 0.6052 - val_recall_1: 0.3216 - val_precision_1: 0.7719
# Epoch 2/100
# 335/335 [==============================] - 84s 252ms/step - loss: 0.6034 - binary_accuracy: 0.6751 - recall_1: 0.6696 - precision_1: 0.6748 - val_loss: 0.7226 - val_binary_accuracy: 0.6121 - val_recall_1: 0.3238 - val_precision_1: 0.7946
# Epoch 3/100
# 335/335 [==============================] - 84s 251ms/step - loss: 0.5716 - binary_accuracy: 0.6998 - recall_1: 0.6976 - precision_1: 0.6984 - val_loss: 0.6800 - val_binary_accuracy: 0.6343 - val_recall_1: 0.8534 - val_precision_1: 0.5996
# Epoch 4/100
# 335/335 [==============================] - 84s 251ms/step - loss: 0.5496 - binary_accuracy: 0.7149 - recall_1: 0.7092 - precision_1: 0.7152 - val_loss: 0.6105 - val_binary_accuracy: 0.6736 - val_recall_1: 0.7610 - val_precision_1: 0.6553
# Epoch 5/100
# 335/335 [==============================] - 84s 250ms/step - loss: 0.5128 - binary_accuracy: 0.7442 - recall_1: 0.7369 - precision_1: 0.7457 - val_loss: 0.6213 - val_binary_accuracy: 0.6777 - val_recall_1: 0.6232 - val_precision_1: 0.7101
# Epoch 6/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4988 - binary_accuracy: 0.7500 - recall_1: 0.7444 - precision_1: 0.7508
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 335/335 [==============================] - 84s 250ms/step - loss: 0.4988 - binary_accuracy: 0.7500 - recall_1: 0.7444 - precision_1: 0.7508 - val_loss: 0.6199 - val_binary_accuracy: 0.6873 - val_recall_1: 0.5921 - val_precision_1: 0.7431
# Epoch 7/100
# 335/335 [==============================] - 84s 250ms/step - loss: 0.4398 - binary_accuracy: 0.7962 - recall_1: 0.7885 - precision_1: 0.7991 - val_loss: 0.5766 - val_binary_accuracy: 0.7029 - val_recall_1: 0.6484 - val_precision_1: 0.7379
# Epoch 8/100
# 335/335 [==============================] - 84s 250ms/step - loss: 0.4260 - binary_accuracy: 0.8035 - recall_1: 0.7971 - precision_1: 0.8057 - val_loss: 0.5726 - val_binary_accuracy: 0.7093 - val_recall_1: 0.6875 - val_precision_1: 0.7279
# Epoch 9/100
# 335/335 [==============================] - 84s 251ms/step - loss: 0.4195 - binary_accuracy: 0.8083 - recall_1: 0.8049 - precision_1: 0.8088 - val_loss: 0.5724 - val_binary_accuracy: 0.7091 - val_recall_1: 0.6915 - val_precision_1: 0.7257
# Epoch 10/100
# 335/335 [==============================] - 84s 251ms/step - loss: 0.4135 - binary_accuracy: 0.8114 - recall_1: 0.8071 - precision_1: 0.8126 - val_loss: 0.5715 - val_binary_accuracy: 0.7082 - val_recall_1: 0.6933 - val_precision_1: 0.7235
# Epoch 11/100
# 335/335 [==============================] - 84s 250ms/step - loss: 0.4079 - binary_accuracy: 0.8147 - recall_1: 0.8095 - precision_1: 0.8163 - val_loss: 0.5739 - val_binary_accuracy: 0.7068 - val_recall_1: 0.6838 - val_precision_1: 0.7260
# Epoch 12/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4032 - binary_accuracy: 0.8179 - recall_1: 0.8144 - precision_1: 0.8186
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 335/335 [==============================] - 84s 251ms/step - loss: 0.4032 - binary_accuracy: 0.8179 - recall_1: 0.8144 - precision_1: 0.8186 - val_loss: 0.5738 - val_binary_accuracy: 0.7106 - val_recall_1: 0.7021 - val_precision_1: 0.7230
# Epoch 13/100
# 335/335 [==============================] - 84s 251ms/step - loss: 0.3971 - binary_accuracy: 0.8213 - recall_1: 0.8141 - precision_1: 0.8244 - val_loss: 0.5733 - val_binary_accuracy: 0.7117 - val_recall_1: 0.7025 - val_precision_1: 0.7245
# Epoch 00013: early stopping
# --------------------Testing Result--------------------
# 118/118 [==============================] - 9s 79ms/step - loss: 0.5766 - binary_accuracy: 0.7192 - recall_1: 0.7032 - precision_1: 0.6531
# --------------------Saving Model--------------------
# saving model to: /content/drive/MyDrive/MinervaModel/ImageNetXceptionBinaryCrossEntropyAdams
# ####################Loss: BinaryCrossEntropy Optimizer: SGD####################
# --------------------Get Pretrained Model--------------------
# --------------------Setup Model--------------------
# --------------------Freezed Training--------------------
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid_1 (Tenso [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 2,049
# Non-trainable params: 20,861,480
# _________________________________________________________________
# None
# Epoch 1/100
# 335/335 [==============================] - 36s 108ms/step - loss: 452.1165 - binary_accuracy: 0.5057 - recall_2: 0.4989 - precision_2: 0.5032 - val_loss: 861.4213 - val_binary_accuracy: 0.4895 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00
# Epoch 2/100
# 335/335 [==============================] - 33s 98ms/step - loss: 420.0999 - binary_accuracy: 0.5129 - recall_2: 0.5038 - precision_2: 0.5105 - val_loss: 544.9310 - val_binary_accuracy: 0.5137 - val_recall_2: 0.9967 - val_precision_2: 0.5122
# Epoch 3/100
# 335/335 [==============================] - 33s 97ms/step - loss: 407.4818 - binary_accuracy: 0.5151 - recall_2: 0.5101 - precision_2: 0.5126 - val_loss: 261.7917 - val_binary_accuracy: 0.5346 - val_recall_2: 0.1243 - val_precision_2: 0.7763
# Epoch 4/100
# 335/335 [==============================] - 33s 97ms/step - loss: 377.9373 - binary_accuracy: 0.5261 - recall_2: 0.5188 - precision_2: 0.5238 - val_loss: 570.3351 - val_binary_accuracy: 0.4924 - val_recall_2: 0.0077 - val_precision_2: 0.8077
# Epoch 5/100
# 335/335 [==============================] - 33s 97ms/step - loss: 371.9048 - binary_accuracy: 0.5285 - recall_2: 0.5219 - precision_2: 0.5262 - val_loss: 258.7583 - val_binary_accuracy: 0.5477 - val_recall_2: 0.1590 - val_precision_2: 0.7796
# Epoch 6/100
# 335/335 [==============================] - 33s 97ms/step - loss: 362.5027 - binary_accuracy: 0.5359 - recall_2: 0.5293 - precision_2: 0.5338 - val_loss: 350.8489 - val_binary_accuracy: 0.5341 - val_recall_2: 0.9671 - val_precision_2: 0.5236
# Epoch 7/100
# 335/335 [==============================] - 32s 96ms/step - loss: 347.6214 - binary_accuracy: 0.5386 - recall_2: 0.5321 - precision_2: 0.5365 - val_loss: 385.7632 - val_binary_accuracy: 0.5283 - val_recall_2: 0.9733 - val_precision_2: 0.5203
# Epoch 8/100
# 335/335 [==============================] - 32s 97ms/step - loss: 350.4514 - binary_accuracy: 0.5383 - recall_2: 0.5336 - precision_2: 0.5360 - val_loss: 308.2618 - val_binary_accuracy: 0.5370 - val_recall_2: 0.1232 - val_precision_2: 0.8043
# Epoch 00008: early stopping
# --------------------Fine Tunning--------------------
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid_1 (Tenso [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 20,809,001
# Non-trainable params: 54,528
# _________________________________________________________________
# None
# Epoch 1/100
#   2/335 [..............................] - ETA: 39s - loss: 6642.9658 - binary_accuracy: 0.4609 - recall_3: 0.5167 - precision_3: 0.4366WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0729s vs `on_train_batch_end` time: 0.1655s). Check your callbacks.
# 335/335 [==============================] - 83s 249ms/step - loss: 41.7191 - binary_accuracy: 0.5227 - recall_3: 0.5283 - precision_3: 0.5198 - val_loss: 0.7122 - val_binary_accuracy: 0.5221 - val_recall_3: 0.8735 - val_precision_3: 0.5190
# Epoch 2/100
# 335/335 [==============================] - 83s 247ms/step - loss: 0.6992 - binary_accuracy: 0.5375 - recall_3: 0.5374 - precision_3: 0.5349 - val_loss: 0.6956 - val_binary_accuracy: 0.5389 - val_recall_3: 0.5062 - val_precision_3: 0.5529
# Epoch 3/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6930 - binary_accuracy: 0.5474 - recall_3: 0.5485 - precision_3: 0.5447 - val_loss: 0.6899 - val_binary_accuracy: 0.5436 - val_recall_3: 0.6484 - val_precision_3: 0.5445
# Epoch 4/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6891 - binary_accuracy: 0.5507 - recall_3: 0.5459 - precision_3: 0.5486 - val_loss: 0.6871 - val_binary_accuracy: 0.5540 - val_recall_3: 0.6118 - val_precision_3: 0.5576
# Epoch 5/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6854 - binary_accuracy: 0.5616 - recall_3: 0.5534 - precision_3: 0.5600 - val_loss: 0.6856 - val_binary_accuracy: 0.5505 - val_recall_3: 0.7493 - val_precision_3: 0.5433
# Epoch 6/100
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6838 - binary_accuracy: 0.5653 - recall_3: 0.5545 - precision_3: 0.5641 - val_loss: 0.6831 - val_binary_accuracy: 0.5589 - val_recall_3: 0.5808 - val_precision_3: 0.5663
# Epoch 7/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6816 - binary_accuracy: 0.5653 - recall_3: 0.5520 - precision_3: 0.5644 - val_loss: 0.6822 - val_binary_accuracy: 0.5648 - val_recall_3: 0.5358 - val_precision_3: 0.5799
# Epoch 8/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6802 - binary_accuracy: 0.5707 - recall_3: 0.5526 - precision_3: 0.5707 - val_loss: 0.6835 - val_binary_accuracy: 0.5753 - val_recall_3: 0.4346 - val_precision_3: 0.6199
# Epoch 9/100
# 335/335 [==============================] - ETA: 0s - loss: 0.6779 - binary_accuracy: 0.5769 - recall_3: 0.5566 - precision_3: 0.5775
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6779 - binary_accuracy: 0.5769 - recall_3: 0.5566 - precision_3: 0.5775 - val_loss: 0.6888 - val_binary_accuracy: 0.5691 - val_recall_3: 0.3118 - val_precision_3: 0.6669
# Epoch 10/100
# 335/335 [==============================] - 83s 248ms/step - loss: 0.6738 - binary_accuracy: 0.5886 - recall_3: 0.5478 - precision_3: 0.5937 - val_loss: 0.6784 - val_binary_accuracy: 0.5689 - val_recall_3: 0.5545 - val_precision_3: 0.5817
# Epoch 11/100
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6733 - binary_accuracy: 0.5872 - recall_3: 0.5586 - precision_3: 0.5898 - val_loss: 0.6779 - val_binary_accuracy: 0.5686 - val_recall_3: 0.5917 - val_precision_3: 0.5753
# Epoch 12/100
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6731 - binary_accuracy: 0.5884 - recall_3: 0.5606 - precision_3: 0.5909 - val_loss: 0.6779 - val_binary_accuracy: 0.5693 - val_recall_3: 0.5775 - val_precision_3: 0.5783
# Epoch 13/100
# 335/335 [==============================] - ETA: 0s - loss: 0.6729 - binary_accuracy: 0.5880 - recall_3: 0.5598 - precision_3: 0.5906
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6729 - binary_accuracy: 0.5880 - recall_3: 0.5598 - precision_3: 0.5906 - val_loss: 0.6783 - val_binary_accuracy: 0.5708 - val_recall_3: 0.5398 - val_precision_3: 0.5866
# Epoch 14/100
# 335/335 [==============================] - 83s 249ms/step - loss: 0.6724 - binary_accuracy: 0.5908 - recall_3: 0.5642 - precision_3: 0.5933 - val_loss: 0.6785 - val_binary_accuracy: 0.5689 - val_recall_3: 0.5303 - val_precision_3: 0.5860
# Epoch 00014: early stopping
# --------------------Testing Result--------------------
# 118/118 [==============================] - 9s 77ms/step - loss: 0.6670 - binary_accuracy: 0.6015 - recall_3: 0.5613 - precision_3: 0.5227
# --------------------Saving Model--------------------
# saving model to: /content/drive/MyDrive/MinervaModel/ImageNetXceptionBinaryCrossEntropySGD
# ####################Loss: BinaryCrossEntropy Optimizer: RMSprop####################
# --------------------Get Pretrained Model--------------------
# --------------------Setup Model--------------------
# --------------------Freezed Training--------------------
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid_2 (Tenso [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 2,049
# Non-trainable params: 20,861,480
# _________________________________________________________________
# None
# Epoch 1/100
# 335/335 [==============================] - 35s 104ms/step - loss: 2.3393 - binary_accuracy: 0.5313 - recall_4: 0.5225 - precision_4: 0.5293 - val_loss: 1.9870 - val_binary_accuracy: 0.5227 - val_recall_4: 0.1246 - val_precision_4: 0.6766
# Epoch 2/100
# 335/335 [==============================] - 34s 101ms/step - loss: 2.1015 - binary_accuracy: 0.5406 - recall_4: 0.5348 - precision_4: 0.5385 - val_loss: 1.9285 - val_binary_accuracy: 0.5272 - val_recall_4: 0.1338 - val_precision_4: 0.6906
# Epoch 3/100
# 335/335 [==============================] - 34s 102ms/step - loss: 2.0572 - binary_accuracy: 0.5431 - recall_4: 0.5335 - precision_4: 0.5413 - val_loss: 1.4402 - val_binary_accuracy: 0.5775 - val_recall_4: 0.8702 - val_precision_4: 0.5550
# Epoch 4/100
# 335/335 [==============================] - 33s 97ms/step - loss: 2.0101 - binary_accuracy: 0.5444 - recall_4: 0.5408 - precision_4: 0.5421 - val_loss: 1.4977 - val_binary_accuracy: 0.5757 - val_recall_4: 0.8754 - val_precision_4: 0.5534
# Epoch 5/100
# 335/335 [==============================] - 33s 100ms/step - loss: 2.0462 - binary_accuracy: 0.5406 - recall_4: 0.5339 - precision_4: 0.5386 - val_loss: 1.9163 - val_binary_accuracy: 0.5581 - val_recall_4: 0.9200 - val_precision_4: 0.5394
# Epoch 6/100
# 335/335 [==============================] - 33s 99ms/step - loss: 1.9796 - binary_accuracy: 0.5558 - recall_4: 0.5503 - precision_4: 0.5539 - val_loss: 1.5078 - val_binary_accuracy: 0.5843 - val_recall_4: 0.8681 - val_precision_4: 0.5599
# Epoch 00006: early stopping
# --------------------Fine Tunning--------------------
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2049
# _________________________________________________________________
# tf_op_layer_Sigmoid_2 (Tenso [(None, 1)]               0
# =================================================================
# Total params: 20,863,529
# Trainable params: 20,809,001
# Non-trainable params: 54,528
# _________________________________________________________________
# None
# Epoch 1/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.8349 - binary_accuracy: 0.5896 - recall_5: 0.5782 - precision_5: 0.5891 - val_loss: 0.8416 - val_binary_accuracy: 0.5712 - val_recall_5: 0.8958 - val_precision_5: 0.5491
# Epoch 2/100
# 335/335 [==============================] - 86s 256ms/step - loss: 0.6290 - binary_accuracy: 0.6467 - recall_5: 0.6399 - precision_5: 0.6463 - val_loss: 0.6384 - val_binary_accuracy: 0.6341 - val_recall_5: 0.8194 - val_precision_5: 0.6045
# Epoch 3/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.5940 - binary_accuracy: 0.6788 - recall_5: 0.6688 - precision_5: 0.6801 - val_loss: 0.6093 - val_binary_accuracy: 0.6615 - val_recall_5: 0.7789 - val_precision_5: 0.6380
# Epoch 4/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.5682 - binary_accuracy: 0.7005 - recall_5: 0.6853 - precision_5: 0.7045 - val_loss: 0.5995 - val_binary_accuracy: 0.6725 - val_recall_5: 0.7902 - val_precision_5: 0.6467
# Epoch 5/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.5448 - binary_accuracy: 0.7200 - recall_5: 0.7062 - precision_5: 0.7241 - val_loss: 0.5679 - val_binary_accuracy: 0.7018 - val_recall_5: 0.7186 - val_precision_5: 0.7037
# Epoch 6/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.5221 - binary_accuracy: 0.7333 - recall_5: 0.7181 - precision_5: 0.7384 - val_loss: 0.5816 - val_binary_accuracy: 0.7005 - val_recall_5: 0.6009 - val_precision_5: 0.7622
# Epoch 7/100
# 335/335 [==============================] - ETA: 0s - loss: 0.5040 - binary_accuracy: 0.7468 - recall_5: 0.7316 - precision_5: 0.7525
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 335/335 [==============================] - 86s 257ms/step - loss: 0.5040 - binary_accuracy: 0.7468 - recall_5: 0.7316 - precision_5: 0.7525 - val_loss: 0.7026 - val_binary_accuracy: 0.6445 - val_recall_5: 0.3586 - val_precision_5: 0.8674
# Epoch 8/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.4491 - binary_accuracy: 0.7837 - recall_5: 0.7651 - precision_5: 0.7928 - val_loss: 0.5572 - val_binary_accuracy: 0.7195 - val_recall_5: 0.6871 - val_precision_5: 0.7440
# Epoch 9/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.4380 - binary_accuracy: 0.7922 - recall_5: 0.7810 - precision_5: 0.7971 - val_loss: 0.5623 - val_binary_accuracy: 0.7195 - val_recall_5: 0.6659 - val_precision_5: 0.7557
# Epoch 10/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4326 - binary_accuracy: 0.7931 - recall_5: 0.7801 - precision_5: 0.7992
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4326 - binary_accuracy: 0.7931 - recall_5: 0.7801 - precision_5: 0.7992 - val_loss: 0.5606 - val_binary_accuracy: 0.7199 - val_recall_5: 0.6908 - val_precision_5: 0.7426
# Epoch 11/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.4269 - binary_accuracy: 0.7967 - recall_5: 0.7832 - precision_5: 0.8031 - val_loss: 0.5559 - val_binary_accuracy: 0.7223 - val_recall_5: 0.7124 - val_precision_5: 0.7355
# Epoch 12/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4249 - binary_accuracy: 0.7979 - recall_5: 0.7850 - precision_5: 0.8040 - val_loss: 0.5554 - val_binary_accuracy: 0.7216 - val_recall_5: 0.7131 - val_precision_5: 0.7340
# Epoch 13/100
# 335/335 [==============================] - 87s 258ms/step - loss: 0.4241 - binary_accuracy: 0.7983 - recall_5: 0.7865 - precision_5: 0.8038 - val_loss: 0.5553 - val_binary_accuracy: 0.7210 - val_recall_5: 0.7113 - val_precision_5: 0.7341
# Epoch 14/100
# 335/335 [==============================] - 87s 259ms/step - loss: 0.4234 - binary_accuracy: 0.7995 - recall_5: 0.7878 - precision_5: 0.8050 - val_loss: 0.5553 - val_binary_accuracy: 0.7216 - val_recall_5: 0.7135 - val_precision_5: 0.7338
# Epoch 15/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4228 - binary_accuracy: 0.7996 - recall_5: 0.7878 - precision_5: 0.8051
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 335/335 [==============================] - 87s 259ms/step - loss: 0.4228 - binary_accuracy: 0.7996 - recall_5: 0.7878 - precision_5: 0.8051 - val_loss: 0.5554 - val_binary_accuracy: 0.7214 - val_recall_5: 0.7116 - val_precision_5: 0.7344
# Epoch 16/100
# 335/335 [==============================] - 87s 259ms/step - loss: 0.4220 - binary_accuracy: 0.7993 - recall_5: 0.7862 - precision_5: 0.8056 - val_loss: 0.5551 - val_binary_accuracy: 0.7208 - val_recall_5: 0.7131 - val_precision_5: 0.7329
# Epoch 17/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4218 - binary_accuracy: 0.7992 - recall_5: 0.7871 - precision_5: 0.8049 - val_loss: 0.5550 - val_binary_accuracy: 0.7214 - val_recall_5: 0.7142 - val_precision_5: 0.7332
# Epoch 18/100
# 335/335 [==============================] - 87s 259ms/step - loss: 0.4218 - binary_accuracy: 0.7995 - recall_5: 0.7878 - precision_5: 0.8049 - val_loss: 0.5549 - val_binary_accuracy: 0.7221 - val_recall_5: 0.7153 - val_precision_5: 0.7338
# Epoch 19/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4217 - binary_accuracy: 0.7998 - recall_5: 0.7888 - precision_5: 0.8049 - val_loss: 0.5549 - val_binary_accuracy: 0.7223 - val_recall_5: 0.7167 - val_precision_5: 0.7334
# Epoch 20/100
# 335/335 [==============================] - 87s 259ms/step - loss: 0.4216 - binary_accuracy: 0.8001 - recall_5: 0.7893 - precision_5: 0.8050 - val_loss: 0.5548 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 21/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4215 - binary_accuracy: 0.8001 - recall_5: 0.7892 - precision_5: 0.8050
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 335/335 [==============================] - 87s 258ms/step - loss: 0.4215 - binary_accuracy: 0.8001 - recall_5: 0.7892 - precision_5: 0.8050 - val_loss: 0.5548 - val_binary_accuracy: 0.7225 - val_recall_5: 0.7167 - val_precision_5: 0.7336
# Epoch 22/100
# 335/335 [==============================] - 87s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7885 - precision_5: 0.8055 - val_loss: 0.5548 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 23/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7885 - precision_5: 0.8055 - val_loss: 0.5548 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 24/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7885 - precision_5: 0.8054 - val_loss: 0.5548 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 25/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7885 - precision_5: 0.8054
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# 335/335 [==============================] - 86s 257ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7885 - precision_5: 0.8054 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 26/100
# 335/335 [==============================] - 86s 257ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 27/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 28/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 29/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999092680235e-13.
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 30/100
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 31/100
# 335/335 [==============================] - ETA: 0s - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.9999988758398e-14.
# 335/335 [==============================] - 86s 258ms/step - loss: 0.4214 - binary_accuracy: 0.8001 - recall_5: 0.7887 - precision_5: 0.8055 - val_loss: 0.5547 - val_binary_accuracy: 0.7227 - val_recall_5: 0.7171 - val_precision_5: 0.7337
# Epoch 00031: early stopping
# --------------------Testing Result--------------------
# 118/118 [==============================] - 10s 82ms/step - loss: 0.5604 - binary_accuracy: 0.7237 - recall_5: 0.7080 - precision_5: 0.6583
# --------------------Saving Model--------------------
# saving model to: /content/drive/MyDrive/MinervaModel/ImageNetXceptionBinaryCrossEntropyRMSprop

# %% [markdown]
# ### Visualization

# %%
import pickle
f = open(savePath+"ImageNetXceptionResultDic.pkl","wb")
pickle.dump(resultsForGraph,f)
f.close()

# %%
epochs = {
            "ImageNetXceptionBinaryCrossEntropyAdams": (13, 8), 
            "ImageNetXceptionBinaryCrossEntropySGD": (8, 14),
            "ImageNetXceptionBinaryCrossEntropyRMSprop": (6, 31)
          }

# %%
for name, v in resultsForGraph.items():
    acc, loss, val_acc, val_loss, result = v
    print("Accuracy: "+str(result[1])+ " Recall: "+str(result[2])+" Precision: "+str(result[3]))
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.ylim([min(val_acc)-.1, 1.0])
    initial_epochs = epochs[name][0]
    plt.plot([initial_epochs-1,initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy for '+ name)

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.ylim([min(loss)-.1, max(val_loss)+.1])
    plt.plot([initial_epochs-1,initial_epochs-1],
          plt.ylim(), label='Start Fine Tuning') 
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss for '+name)
    plt.xlabel('epoch')
    plt.show()
# Out:
# Accuracy: 0.7192144393920898 Recall: 0.7031992673873901 Precision: 0.6531332731246948
# Accuracy: 0.6015127301216125 Recall: 0.5612923502922058 Precision: 0.522713840007782
# Accuracy: 0.7237260937690735 Recall: 0.7079505920410156 Precision: 0.6583210825920105
