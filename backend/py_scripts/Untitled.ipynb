# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
doc = """
         Supervised learning is the machine learning task of 
         learning a function that maps an input to an output based 
         on example input-output pairs.[1] It infers a function 
         from labeled training data consisting of a set of 
         training examples.[2] In supervised learning, each 
         example is a pair consisting of an input object 
         (typically a vector) and a desired output value (also 
         called the supervisory signal). A supervised learning 
         algorithm analyzes the training data and produces an 
         inferred function, which can be used for mapping new 
         examples. An optimal scenario will allow for the algorithm 
         to correctly determine the class labels for unseen 
         instances. This requires the learning algorithm to  
         generalize from the training data to unseen situations 
         in a 'reasonable' way (see inductive bias).
      """

# %%
n_gram_range = (1, 2)
stop_words = 'english'

# Extract candidate words/phrases
count = CountVectorizer(ngram_range=n_gram_range, stop_words=stop_words).fit([docs])
candidates = count.get_feature_names()

# %%
candidates
# Out:
# ['10',
#  '10 20',
#  '10 67',
#  '10 block',
#  '10 blocks',
#  '10 count',
#  '10 going',
#  '10 tens',
#  '10 times',
#  '110',
#  '110 number',
#  '110 starting',
#  '13',
#  '13 ll',
#  '18',
#  '18 57',
#  '18 77',
#  '18 number',
#  '20',
#  '20 21',
#  '20 30',
#  '20 just',
#  '20 know',
#  '20 let',
#  '21',
#  '21 22',
#  '21 57',
#  '21 yep',
#  '22',
#  '22 23',
#  '22 greater',
#  '22 know',
#  '22 let',
#  '22 number',
#  '23',
#  '23 24',
#  '24',
#  '24 25',
#  '25',
#  '25 25',
#  '25 26',
#  '25 31',
#  '25 54',
#  '25 greater',
#  '25 look',
#  '25 looks',
#  '25 remember',
#  '25 tens',
#  '26',
#  '26 27',
#  '27',
#  '27 28',
#  '28',
#  '28 28',
#  '28 base',
#  '28 greater',
#  '28 let',
#  '30',
#  '30 40',
#  '31',
#  '31 31',
#  '31 greater',
#  '31 little',
#  '31 look',
#  '31 number',
#  '31 numbers',
#  '40',
#  '40 40',
#  '40 50',
#  '40 cubes',
#  '40 let',
#  '40 long',
#  '41',
#  '41 42',
#  '42',
#  '42 43',
#  '42 number',
#  '43',
#  '43 44',
#  '44',
#  '44 45',
#  '45',
#  '45 46',
#  '45 54',
#  '45 let',
#  '45 means',
#  '45 number',
#  '46',
#  '46 47',
#  '47',
#  '47 47',
#  '47 cubes',
#  '50',
#  '50 greater',
#  '51',
#  '51 52',
#  '52',
#  '52 53',
#  '53',
#  '53 54',
#  '53 way',
#  '54',
#  '54 45',
#  '54 53',
#  '54 54',
#  '54 greater',
#  '54 know',
#  '54 number',
#  '54 yes',
#  '55',
#  '55 54',
#  '56',
#  '56 55',
#  '56 57',
#  '56 going',
#  '56 okay',
#  '57',
#  '57 31',
#  '57 56',
#  '57 57',
#  '57 58',
#  '57 99',
#  '57 actually',
#  '57 bigger',
#  '57 don',
#  '57 gonna',
#  '57 greater',
#  '57 let',
#  '57 like',
#  '57 number',
#  '57 okay',
#  '57 yeah',
#  '58',
#  '58 57',
#  '58 59',
#  '58 number',
#  '59',
#  '59 okay',
#  '60',
#  '60 56',
#  '60 examples',
#  '60 greater',
#  '67',
#  '67 10',
#  '77',
#  '77 57',
#  '77 77',
#  '80',
#  '80 larger',
#  '80 let',
#  '81',
#  '81 82',
#  '82',
#  '82 83',
#  '83',
#  '83 84',
#  '84',
#  '84 85',
#  '85',
#  '85 81',
#  '85 largely',
#  '85 number',
#  '99',
#  '99 21',
#  '99 big',
#  'actually',
#  'actually equals',
#  'ahead',
#  'ahead check',
#  'ahead count',
#  'alright',
#  'alright welcome',
#  'apps',
#  'apps comments',
#  'avenue',
#  'avenue haven',
#  'axe',
#  'axe compare',
#  'base',
#  'base 10',
#  'base blocks',
#  'belongs',
#  'belongs right',
#  'big',
#  'big 21',
#  'bigger',
#  'bigger 57',
#  'bigger logs',
#  'bigger number',
#  'bigger numbers',
#  'bit',
#  'bit tricky',
#  'block',
#  'block cube',
#  'blocks',
#  'blocks count',
#  'blocks just',
#  'blocks let',
#  'blocks ll',
#  'blocks number',
#  'blocks really',
#  'blocks remember',
#  'blocks represent',
#  'blocks starting',
#  'blur',
#  'blur right',
#  'box',
#  'box let',
#  'boys',
#  'boys girls',
#  'called',
#  'called long',
#  'car',
#  'car new',
#  'cars',
#  'cars getting',
#  'cars number',
#  'cars numbers',
#  'cars participate',
#  'channel',
#  'channel stay',
#  'chasing',
#  'chasing smaller',
#  'check',
#  'check box',
#  'check correct',
#  'check pairs',
#  'check way',
#  'choice',
#  'choice 31',
#  'choices',
#  'choices 60',
#  'choices ve',
#  'come',
#  'come let',
#  'come okay',
#  'come right',
#  'comments',
#  'compare',
#  'compare fours',
#  'compare know',
#  'compare number',
#  'compare numbers',
#  'compare ones',
#  'compare tens',
#  'compare using',
#  'comparing',
#  'comparing numbers',
#  'comparison',
#  'comparison correct',
#  'comparison similar',
#  'comparison symbol',
#  'comparison symbols',
#  'confused',
#  'confused 57',
#  'connect',
#  'connect numbers',
#  'correct',
#  'correct ahead',
#  'correct check',
#  'correct let',
#  'correct numbers',
#  'correct okay',
#  'correct remember',
#  'count',
#  'count 10',
#  'count 20',
#  'count 51',
#  'count base',
#  'count belongs',
#  'count cubes',
#  'count home',
#  'count loggers',
#  'count ones',
#  'count tens',
#  'counted',
#  'counted cubes',
#  'counting',
#  'counting base',
#  'counting logs',
#  'counting long',
#  'couple',
#  'couple choices',
#  'couple long',
#  'cube',
#  'cube cube',
#  'cube know',
#  'cube worth',
#  'cubed',
#  'cubed number',
#  'cubes',
#  'cubes blocks',
#  'cubes cubes',
#  'cubes didn',
#  'cubes gives',
#  'cubes just',
#  'cubes let',
#  'cubes long',
#  'cubes making',
#  'cubes represent',
#  'cubes right',
#  'cubes seven',
#  'cubes thirteen',
#  'cubes wanted',
#  'cubes worth',
#  'definitely',
#  'definitely greater',
#  'didn',
#  'didn avenue',
#  'didn great',
#  'didn talk',
#  'digit',
#  'digit tens',
#  'dion',
#  'dion let',
#  'direction',
#  'direction 18',
#  'direction 99',
#  'directions',
#  'directions say',
#  'directions start',
#  'does',
#  'does number',
#  'doing',
#  'doing good',
#  'don',
#  'don confused',
#  'don want',
#  'draw',
#  'draw comparison',
#  'draw line',
#  'draw number',
#  'easier',
#  'easier look',
#  'eat',
#  'eat bigger',
#  'eating',
#  'eating 54',
#  'end',
#  'end thanks',
#  'ends',
#  'ends paris',
#  'equal',
#  'equal 80',
#  'equal comparison',
#  'equals',
#  'equals 20',
#  'equals means',
#  'example',
#  'example 56',
#  'example comparison',
#  'example number',
#  'example problem',
#  'example wow',
#  'examples',
#  'examples numbers',
#  'facing',
#  'facing right',
#  'far',
#  'far left',
#  'feared',
#  'feared logs',
#  'figure',
#  'figure number',
#  'final',
#  'final count',
#  'fives',
#  'fives number',
#  'fours',
#  'fours fives',
#  'fun',
#  'fun directions',
#  'getting',
#  'getting ready',
#  'girls',
#  'girls ll',
#  'girls long',
#  'girls racetrack',
#  'girls teacher',
#  'girls time',
#  'gives',
#  'gives 41',
#  'going',
#  'going 10',
#  'going 56',
#  'going 57',
#  'going bigger',
#  'going compare',
#  'going comparing',
#  'going doing',
#  'going greater',
#  'going looking',
#  'going way',
#  'gonna',
#  'gonna 31',
#  'gonna 57',
#  'gonna going',
#  'gonna let',
#  'gonna lots',
#  'gonna okay',
#  'gonna right',
#  'gonna today',
#  'gonna way',
#  'good',
#  'good ve',
#  'got',
#  'got 57',
#  'got choices',
#  'got correct',
#  'got couple',
#  'got thanksgiving',
#  'got turkey',
#  'great',
#  'great job',
#  'greater',
#  'greater 13',
#  'greater 25',
#  'greater 28',
#  'greater 45',
#  'greater 57',
#  'greater end',
#  'greater going',
#  'greater means',
#  'greater number',
#  'greater numbers',
#  'greater right',
#  'greater sign',
#  'greater tens',
#  'greater true',
#  'greater value',
#  'haven',
#  'haven counted',
#  'hear',
#  'hear cars',
#  'hello',
#  'hello boys',
#  'hello worth',
#  'helmet',
#  'helmet number',
#  'help',
#  'help compare',
#  'help numbers',
#  'help prepare',
#  'help turkey',
#  'home',
#  'home 41',
#  'important',
#  'important things',
#  'individual',
#  'individual cubes',
#  'information',
#  'information tell',
#  'job',
#  'job race',
#  'job today',
#  'just',
#  'just compare',
#  'just count',
#  'just counting',
#  'just final',
#  'just long',
#  'just sure',
#  'know',
#  'know 20',
#  'know 22',
#  'know base',
#  'know correct',
#  'know equals',
#  'know long',
#  'know place',
#  'know value',
#  'largely',
#  'largely comparison',
#  'larger',
#  'larger correct',
#  'larger just',
#  'largest',
#  'largest place',
#  'left',
#  'left 85',
#  'left compare',
#  'left cubes',
#  'left largest',
#  'left let',
#  'left means',
#  'left ok',
#  'left tens',
#  'let',
#  'let cars',
#  'let check',
#  'let come',
#  'let compare',
#  'let count',
#  'let cubes',
#  'let dion',
#  'let direction',
#  'let draw',
#  'let ends',
#  'let figure',
#  'let going',
#  'let just',
#  'let look',
#  'let number',
#  'let ones',
#  'let problem',
#  'let read',
#  'let remind',
#  'let say',
#  'let shot',
#  'let start',
#  'let started',
#  'let think',
#  'let use',
#  'like',
#  'like bigger',
#  'like example',
#  'like okay',
#  'like racing',
#  'like whoa',
#  'line',
#  'line 57',
#  'line connect',
#  'line gonna',
#  'line ll',
#  'line okay',
#  'line remember',
#  'links',
#  'links apps',
#  'little',
#  'little bit',
#  'little reminder',
#  'll',
#  'll draw',
#  'll help',
#  'll time',
#  'll true',
#  'loggers',
#  'loggers number',
#  'logs',
#  'logs left',
#  'logs miss',
#  'logs remember',
#  'logs think',
#  'logs worth',
#  'long',
#  'long called',
#  'long cubes',
#  'long hello',
#  'long individual',
#  'long know',
#  'long let',
#  'long long',
#  'long number',
#  'long representing',
#  'long represents',
#  'long starting',
#  'long tens',
#  'long worth',
#  'longs',
#  'longs let',
#  'look',
#  'look 18',
#  'look car',
#  'look digit',
#  'look direction',
#  'look example',
#  'look largest',
#  'look left',
#  'look like',
#  'look number',
#  'look picture',
#  'look row',
#  'look way',
#  'looking',
#  'looking numbers',
#  'looking worksheet',
#  'looks',
#  'looks like',
#  'lot',
#  'lot longs',
#  'lots',
#  'lots fun',
#  'lumber',
#  'lumber number',
#  'lungs',
#  'lungs worth',
#  'making',
#  'making 85',
#  'mark',
#  'mark set',
#  'maze',
#  'maze didn',
#  'means',
#  'means 31',
#  'means 40',
#  'means 45',
#  'means equal',
#  'means need',
#  'middle',
#  'middle lumber',
#  'mike',
#  'mike today',
#  'minute',
#  'minute gonna',
#  'miss',
#  'miss number',
#  'mouth',
#  'mouth open',
#  'need',
#  'need need',
#  'need number',
#  'need way',
#  'new',
#  'new number',
#  'new videos',
#  'nice',
#  'nice gonna',
#  'nice job',
#  'nice little',
#  'number',
#  'number 22',
#  'number 25',
#  'number 31',
#  'number 45',
#  'number 54',
#  'number 57',
#  'number couple',
#  'number definitely',
#  'number eat',
#  'number feared',
#  'number greater',
#  'number larger',
#  'number left',
#  'number let',
#  'number line',
#  'number long',
#  'number number',
#  'number probably',
#  'number quickly',
#  'number right',
#  'number sign',
#  'number tens',
#  'numbers',
#  'numbers 57',
#  'numbers base',
#  'numbers check',
#  'numbers easier',
#  'numbers equal',
#  'numbers far',
#  'numbers going',
#  'numbers greater',
#  'numbers let',
#  'numbers looking',
#  'numbers mark',
#  'numbers need',
#  'numbers number',
#  'numbers people',
#  'numbers remember',
#  'numbers started',
#  'numbers tens',
#  'numbers using',
#  'numbers ve',
#  'ok',
#  'ok tens',
#  'okay',
#  'okay 57',
#  'okay 60',
#  'okay come',
#  'okay let',
#  'okay middle',
#  'okay nice',
#  'okay number',
#  'okay trying',
#  'ones',
#  'ones 20',
#  'ones cubed',
#  'ones let',
#  'ones nice',
#  'ones pair',
#  'ones place',
#  'open',
#  'open bigger',
#  'pair',
#  'pair compare',
#  'pairs',
#  'pairs signs',
#  'paris',
#  'paris simple',
#  'participate',
#  'participate race',
#  'people',
#  'people ahead',
#  'phenom',
#  'phenom blur',
#  'picture',
#  'picture long',
#  'place',
#  'place 54',
#  'place cars',
#  'place compare',
#  'place greater',
#  'place help',
#  'place just',
#  'place mark',
#  'place numbers',
#  'place value',
#  'plus',
#  'plus seven',
#  'pointed',
#  'pointed chasing',
#  'prepare',
#  'prepare numbers',
#  'probably',
#  'probably smaller',
#  'problem',
#  'problem comparing',
#  'problem let',
#  'problem number',
#  'quickly',
#  'quickly simply',
#  'race',
#  'race cars',
#  'race let',
#  'race today',
#  'racetrack',
#  'racetrack ready',
#  'racing',
#  'racing helmet',
#  'read',
#  'read directions',
#  'ready',
#  'ready compare',
#  'ready race',
#  'really',
#  'really important',
#  'really represent',
#  'really work',
#  'remember',
#  'remember boys',
#  'remember count',
#  'remember don',
#  'remember logs',
#  'remember look',
#  'remember start',
#  'remind',
#  'remind really',
#  'reminder',
#  'reminder reminding',
#  'reminding',
#  'reminding lungs',
#  'represent',
#  'represent number',
#  'represent ones',
#  'represent way',
#  'representing',
#  'representing long',
#  'represents',
#  'represents count',
#  'right',
#  'right 10',
#  'right 110',
#  'right 18',
#  'right 41',
#  'right going',
#  'right long',
#  'right looking',
#  'right numbers',
#  'right phenom',
#  'right start',
#  'right ve',
#  'right way',
#  'row',
#  'row let',
#  'say',
#  'say example',
#  'say help',
#  'set',
#  'set like',
#  'set thanks',
#  'seven',
#  'seven left',
#  'seven plus',
#  'seven seven',
#  'shot',
#  'shot 10',
#  'shot number',
#  'shows',
#  'shows 28',
#  'shows 80',
#  'sign',
#  'sign look',
#  'sign small',
#  'signs',
#  'signs comparison',
#  'similar',
#  'similar shows',
#  'simple',
#  'simple facing',
#  'simply',
#  'simply counting',
#  'small',
#  'small pointed',
#  'smaller',
#  'smaller 22',
#  'smaller 57',
#  'smaller number',
#  'start',
#  'start compare',
#  'start counting',
#  'start left',
#  'start logs',
#  'start problem',
#  'start turkey',
#  'started',
#  'started counting',
#  'started let',
#  'started worksheet',
#  'starting',
#  'starting long',
#  'starting think',
#  'stay',
#  'stay updated',
#  'subscribe',
#  'subscribe channel',
#  'sure',
#  'sure just',
#  'symbol',
#  'symbol eating',
#  'symbol got',
#  'symbol mouth',
#  'symbol shows',
#  'symbols',
#  'symbols example',
#  'talk',
#  'talk looking',
#  'teacher',
#  'teacher mike',
#  'tell',
#  'tell compare',
#  'tens',
#  'tens 10',
#  'tens ahead',
#  'tens does',
#  'tens going',
#  'tens help',
#  'tens know',
#  'tens long',
#  'tens means',
#  'tens ones',
#  'tens place',
#  'tens really',
#  'thanks',
#  'thanks watching',
#  'thanksgiving',
#  'thanksgiving themed',
#  'themed',
#  'themed worksheet',
#  'things',
#  'things know',
#  'think',
#  'think 110',
#  'think let',
#  'think minute',
#  'think number',
#  'thirteen',
#  'thirteen know',
#  'tim',
#  'tim cubes',
#  'time',
#  'time alright',
#  'time hello',
#  'times',
#  'times let',
#  'today',
#  'today going',
#  'today numbers',
#  'today subscribe',
#  'tricky',
#  'tricky didn',
#  'true',
#  'true 60',
#  'true check',
#  'trying',
#  'trying way',
#  'turkey',
#  'turkey maze',
#  'turkey okay',
#  'turkey way',
#  'updated',
#  'updated new',
#  'use',
#  'use information',
#  'using',
#  'using base',
#  'using place',
#  'value',
#  'value base',
#  'value compare',
#  'value cube',
#  'value hear',
#  'value start',
#  've',
#  've got',
#  'videos',
#  'videos links',
#  'want',
#  'want way',
#  'wanted',
#  'wanted compare',
#  'watching',
#  'watching boys',
#  'way',
#  'way choice',
#  'way comparison',
#  'way draw',
#  'way gonna',
#  'way got',
#  'way let',
#  'way number',
#  'way okay',
#  'way symbol',
#  'way zero',
#  'welcome',
#  'welcome nice',
#  'whoa',
#  'whoa look',
#  'work',
#  'work let',
#  'worksheet',
#  'worksheet axe',
#  'worksheet gonna',
#  'worksheet let',
#  'worth',
#  'worth 10',
#  'worth 40',
#  'worth just',
#  'worth let',
#  'worth long',
#  'worth tim',
#  'wow',
#  'wow lot',
#  'yeah',
#  'yeah gonna',
#  'yep',
#  'yep smaller',
#  'yes',
#  'yes 25',
#  'zero',
#  'zero right']

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('distilbert-base-nli-mean-tokens')
doc_embedding = model.encode([docs])
candidate_embeddings = model.encode(candidates)

# %%
candidate_embeddings.shape
# Out:
# (949, 768)

# %%
from sklearn.metrics.pairwise import cosine_similarity

top_n = 5
distances = cosine_similarity(doc_embedding, candidate_embeddings)
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]

# %%
keywords
# Out:
# ['race today',
#  'cars participate',
#  'girls racetrack',
#  'race cars',
#  'racing helmet']

# %%
import numpy as np
import itertools

def max_sum_sim(doc_embedding, word_embeddings, words, top_n, nr_candidates):
    # Calculate distances and extract keywords
    distances = cosine_similarity(doc_embedding, candidate_embeddings)
    distances_candidates = cosine_similarity(candidate_embeddings, 
                                            candidate_embeddings)

    # Get top_n words as candidates based on cosine similarity
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # Calculate the combination of words that are the least similar to each other
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=30)
# Out:
# ['40 cubes', 'girls teacher', 'counting base', 'new videos', 'racing helmet']

# %%
from youtube_transcript_api import YouTubeTranscriptApi
raw_transcript = YouTubeTranscriptApi.get_transcript("Qn87cKHa7v4")

# %%
raw_transcript
# Out:
# [{'text': '[Music]', 'start': 0.61, 'duration': 4.99},
#  {'text': 'hello boys and girls we are at the',
#   'start': 12.06,
#   'duration': 6.55},
#  {'text': 'racetrack ready to compare some numbers',
#   'start': 15.7,
#   'duration': 6.15},
#  {'text': "let's see which cars participate in the",
#   'start': 18.61,
#   'duration': 5.64},
#  {'text': 'race today and which numbers we are',
#   'start': 21.85,
#   'duration': 4.98},
#  {'text': 'going to compare you already know about',
#   'start': 24.25,
#   'duration': 5.4},
#  {'text': 'place value and compare numbers using',
#   'start': 26.83,
#   'duration': 6.42},
#  {'text': "base ten blocks now I'll help you find",
#   'start': 29.65,
#   'duration': 5.85},
#  {'text': 'numbers that are greater than or less',
#   'start': 33.25,
#   'duration': 6.36},
#  {'text': 'than other numbers on your mark get set',
#   'start': 35.5,
#   'duration': 8.79},
#  {'text': 'go do you like that racing helmet see',
#   'start': 39.61,
#   'duration': 9.06},
#  {'text': "the number it's number 25 we can look at",
#   'start': 44.29,
#   'duration': 7.38},
#  {'text': 'the digit in the tens place first to',
#   'start': 48.67,
#   'duration': 5.88},
#  {'text': 'help compare numbers how many tens does',
#   'start': 51.67,
#   'duration': 7.889},
#  {'text': 'my number have 25 has two tens', 'start': 54.55, 'duration': 11.7},
#  {'text': "it also has five ones nice job there's",
#   'start': 59.559,
#   'duration': 9.721},
#  {'text': 'one of the race cars now what number is',
#   'start': 66.25,
#   'duration': 10.5},
#  {'text': 'it is 31 greater or less than 25 both 25',
#   'start': 69.28,
#   'duration': 10.26},
#  {'text': 'and 31 have numbers in the tens place',
#   'start': 76.75,
#   'duration': 7.77},
#  {'text': 'see we see that 3 is greater than 2 that',
#   'start': 79.54,
#   'duration': 9.81},
#  {'text': 'means that 31 is greater than 25 we put',
#   'start': 84.52,
#   'duration': 7.2},
#  {'text': 'up the greater than sign with this small',
#   'start': 89.35,
#   'duration': 5.01},
#  {'text': 'pointed side chasing the smaller number',
#   'start': 91.72,
#   'duration': 8.64},
#  {'text': 'so the sign would look like this whoa',
#   'start': 94.36,
#   'duration': 8.579},
#  {'text': "look there's another car with a new",
#   'start': 100.36,
#   'duration': 6.41},
#  {'text': 'number is that number greater than 25',
#   'start': 102.939,
#   'duration': 6.871},
#  {'text': 'well first we can look at the largest',
#   'start': 106.77,
#   'duration': 5.26},
#  {'text': 'place which are the numbers on the far',
#   'start': 109.81,
#   'duration': 5.72},
#  {'text': "left they are the same they're both two",
#   'start': 112.03,
#   'duration': 7.229},
#  {'text': "that's ok if the tens place is the same",
#   'start': 115.53,
#   'duration': 5.83},
#  {'text': 'and then we can just compare the ones',
#   'start': 119.259,
#   'duration': 6.091},
#  {'text': 'place see we can compare using place',
#   'start': 121.36,
#   'duration': 5.22},
#  {'text': 'value', 'start': 125.35, 'duration': 5.64},
#  {'text': 'I can hear some cars getting ready to',
#   'start': 126.58,
#   'duration': 4.92},
#  {'text': 'race', 'start': 130.99, 'duration': 5.25},
#  {'text': "let's compare their numbers do you",
#   'start': 131.5,
#   'duration': 8.27},
#  {'text': 'remember where we start when we compare',
#   'start': 136.24,
#   'duration': 6.18},
#  {'text': 'they both have fours and fives in their',
#   'start': 139.77,
#   'duration': 6.01},
#  {'text': 'number but but one with the five in the',
#   'start': 142.42,
#   'duration': 6.69},
#  {'text': "tens place has a greater value that's",
#   'start': 145.78,
#   'duration': 5.07},
#  {'text': 'why we should always start at the left',
#   'start': 149.11,
#   'duration': 5.58},
#  {'text': 'with the largest place 54 is greater',
#   'start': 150.85,
#   'duration': 7.92},
#  {'text': 'than 45 that also means that 45 is less',
#   'start': 154.69,
#   'duration': 7.83},
#  {'text': 'than 54 do you see another number that',
#   'start': 158.77,
#   'duration': 11.37},
#  {'text': 'is less than 54 yes 25 is less than 54',
#   'start': 162.52,
#   'duration': 11.85},
#  {'text': "it's less than 45 too because number 25",
#   'start': 170.14,
#   'duration': 8.48},
#  {'text': 'only has a 2 in the tens place', 'start': 174.37, 'duration': 4.25},
#  {'text': 'there are 2 more cars are the numbers',
#   'start': 180.27,
#   'duration': 9.55},
#  {'text': 'greater than or less than 25 it looks',
#   'start': 184.18,
#   'duration': 7.26},
#  {'text': 'like they both have bigger numbers in',
#   'start': 189.82,
#   'duration': 3.96},
#  {'text': 'the tens place so they are both greater',
#   'start': 191.44,
#   'duration': 8.61},
#  {'text': 'than 25 remember look left and compare',
#   'start': 193.78,
#   'duration': 9.26},
#  {'text': 'the tens place first', 'start': 200.05, 'duration': 2.99},
#  {'text': 'on your mark get set go', 'start': 203.36, 'duration': 4.83},
#  {'text': 'thanks for watching boys and girls see',
#   'start': 208.58,
#   'duration': 5.31},
#  {'text': 'you next time', 'start': 211.319, 'duration': 2.571},
#  {'text': 'hello boys and girls', 'start': 216.019, 'duration': 3.911},
#  {'text': "it's teacher Mike here and today we're",
#   'start': 217.739,
#   'duration': 3.601},
#  {'text': 'going to be looking at a worksheet that',
#   'start': 219.93,
#   'duration': 4.529},
#  {'text': 'axe us to compare numbers before we get',
#   'start': 221.34,
#   'duration': 5.25},
#  {'text': "started let's remind ourselves to some",
#   'start': 224.459,
#   'duration': 3.721},
#  {'text': 'really important things to know and',
#   'start': 226.59,
#   'duration': 6.6},
#  {'text': 'place value first which base 10 block',
#   'start': 228.18,
#   'duration': 8.46},
#  {'text': 'that you see this is a cube do you know',
#   'start': 233.19,
#   'duration': 6.12},
#  {'text': 'the value of the cube cube is worth just',
#   'start': 236.64,
#   'duration': 6.27},
#  {'text': 'one how about a long you know how much',
#   'start': 239.31,
#   'duration': 6.989},
#  {'text': 'the long is worth well the long is made',
#   'start': 242.91,
#   'duration': 6.51},
#  {'text': 'up of ten individual cubes and therefore',
#   'start': 246.299,
#   'duration': 6.871},
#  {'text': "the long is worth ten let's use this",
#   'start': 249.42,
#   'duration': 5.97},
#  {'text': 'information tell us to compare numbers',
#   'start': 253.17,
#   'duration': 6.33},
#  {'text': "with base ten blocks let's say for",
#   'start': 255.39,
#   'duration': 6.54},
#  {'text': "example we had a number with two Long's",
#   'start': 259.5,
#   'duration': 5.55},
#  {'text': 'and two cubes we wanted to compare this',
#   'start': 261.93,
#   'duration': 5.7},
#  {'text': 'to a number with one long and three',
#   'start': 265.05,
#   'duration': 5.76},
#  {'text': 'cubes well one of these blocks really',
#   'start': 267.63,
#   'duration': 6.06},
#  {'text': 'represent one way we can see what this',
#   'start': 270.81,
#   'duration': 5.37},
#  {'text': 'number is quickly by simply counting the',
#   'start': 273.69,
#   'duration': 5.13},
#  {'text': "base ten blocks starting with the Long's",
#   'start': 276.18,
#   'duration': 5.94},
#  {'text': "so let's give it a shot in this number",
#   'start': 278.82,
#   'duration': 5.31},
#  {'text': "we have one long and that's representing",
#   'start': 282.12,
#   'duration': 4.41},
#  {'text': 'ten and another long and that represents',
#   'start': 284.13,
#   'duration': 5.3},
#  {'text': 'ten so we can count by 10 two times',
#   'start': 286.53,
#   'duration': 7.59},
#  {'text': "let's give it a shot 10 20 now we know",
#   'start': 289.43,
#   'duration': 7.81},
#  {'text': 'we have 20 we can just count on with our',
#   'start': 294.12,
#   'duration': 7.109},
#  {'text': 'other two cubes and represent ones 20 21',
#   'start': 297.24,
#   'duration': 7.64},
#  {'text': '22 so I know that these base 10 blocks',
#   'start': 301.229,
#   'duration': 7.311},
#  {'text': 'represent the number 22 well', 'start': 304.88, 'duration': 6.12},
#  {'text': 'about the number on the right side this',
#   'start': 308.54,
#   'duration': 6.27},
#  {'text': "side I see 110 already I'm starting to",
#   'start': 311.0,
#   'duration': 6.93},
#  {'text': "think if there's only 110 in this number",
#   'start': 314.81,
#   'duration': 6.56},
#  {'text': "it's probably smaller or less than 22",
#   'start': 317.93,
#   'duration': 6.39},
#  {'text': "let's count all the base ten blocks just",
#   'start': 321.37,
#   'duration': 6.37},
#  {'text': 'to be sure after ten we can just count',
#   'start': 324.32,
#   'duration': 7.47},
#  {'text': 'on our three cubes ten eleven twelve',
#   'start': 327.74,
#   'duration': 8.64},
#  {'text': 'thirteen so we know that 22 is greater',
#   'start': 331.79,
#   'duration': 6.96},
#  {'text': "than 13 so we'll draw the comparison",
#   'start': 336.38,
#   'duration': 5.01},
#  {'text': 'symbol with the mouth open towards the',
#   'start': 338.75,
#   'duration': 4.74},
#  {'text': 'bigger number because you will always',
#   'start': 341.39,
#   'duration': 5.97},
#  {'text': "eat the bigger number let's get started",
#   'start': 343.49,
#   'duration': 5.79},
#  {'text': "with our worksheet let's read the",
#   'start': 347.36,
#   'duration': 4.28},
#  {'text': 'directions start with the first problem',
#   'start': 349.28,
#   'duration': 6.27},
#  {'text': 'comparing numbers base ten blocks count',
#   'start': 351.64,
#   'duration': 7.39},
#  {'text': 'tens and ones in each pair and compare',
#   'start': 355.55,
#   'duration': 5.73},
#  {'text': 'the numbers check the pairs where the',
#   'start': 359.03,
#   'duration': 6.06},
#  {'text': 'signs of comparison are correct okay we',
#   'start': 361.28,
#   'duration': 5.28},
#  {'text': 'have a nice little reminder up top',
#   'start': 365.09,
#   'duration': 3.84},
#  {'text': 'reminding us about the lungs or worth',
#   'start': 366.56,
#   'duration': 5.82},
#  {'text': "Tim and the cubes are worth one so let's",
#   'start': 368.93,
#   'duration': 4.92},
#  {'text': 'get started by counting the base ten',
#   'start': 372.38,
#   'duration': 4.23},
#  {'text': 'blocks remember we can count by tens if',
#   'start': 373.85,
#   'duration': 5.73},
#  {'text': "we see it long so let's look at our",
#   'start': 376.61,
#   'duration': 5.73},
#  {'text': "first picture how many Long's are there",
#   'start': 379.58,
#   'duration': 7.47},
#  {'text': "called I see one two three four Long's",
#   'start': 382.34,
#   'duration': 8.22},
#  {'text': "hello that's worth 40 now let's see how",
#   'start': 387.05,
#   'duration': 7.32},
#  {'text': "many cubes we have there's one two three",
#   'start': 390.56,
#   'duration': 7.95},
#  {'text': "four five cubes so let's count home from",
#   'start': 394.37,
#   'duration': 12.21},
#  {'text': 'forty five more 41 42 43 44 45 our first',
#   'start': 398.51,
#   'duration': 11.91},
#  {'text': "number has 45 let's compare it to the",
#   'start': 406.58,
#   'duration': 5.429},
#  {'text': 'number on the right', 'start': 410.42, 'duration': 4.139},
#  {'text': 'we can first start by counting how many',
#   'start': 412.009,
#   'duration': 6.27},
#  {'text': 'logs there well miss number we feared',
#   'start': 414.559,
#   'duration': 11.491},
#  {'text': "there's one two three four five logs do",
#   'start': 418.279,
#   'duration': 9.87},
#  {'text': "think this number with five Long's or",
#   'start': 426.05,
#   'duration': 4.41},
#  {'text': "five tens it's going to be greater or",
#   'start': 428.149,
#   'duration': 4.95},
#  {'text': 'less than forty five how much is five',
#   'start': 430.46,
#   'duration': 5.039},
#  {'text': "tens really work let's just count the",
#   'start': 433.099,
#   'duration': 8.79},
#  {'text': 'tens 10 20 30 40 and 50 so already',
#   'start': 435.499,
#   'duration': 9.241},
#  {'text': "that's greater than 45 let's count the",
#   'start': 441.889,
#   'duration': 4.881},
#  {'text': 'cubes just so we can get a final count',
#   'start': 444.74,
#   'duration': 6.679},
#  {'text': '51 52 53 54', 'start': 446.77, 'duration': 9.28},
#  {'text': "so 54 is greater than 45 let's see if it",
#   'start': 451.419,
#   'duration': 6.31},
#  {'text': 'ends Paris and simple is facing the',
#   'start': 456.05,
#   'duration': 5.519},
#  {'text': 'right way it is the symbol is eating the',
#   'start': 457.729,
#   'duration': 7.23},
#  {'text': '54 so we know this is correct we can go',
#   'start': 461.569,
#   'duration': 5.88},
#  {'text': "ahead and check the box let's take a",
#   'start': 464.959,
#   'duration': 6.121},
#  {'text': 'look at our next example in this problem',
#   'start': 467.449,
#   'duration': 5.911},
#  {'text': 'on the number on the Left we have two',
#   'start': 471.08,
#   'duration': 6.359},
#  {'text': "tens we know that equals 20 let's see",
#   'start': 473.36,
#   'duration': 7.109},
#  {'text': "how many ones we have in let's count",
#   'start': 477.439,
#   'duration': 11.78},
#  {'text': 'from 20 we have 21 22 23 and 24 25 26 27',
#   'start': 480.469,
#   'duration': 10.29},
#  {'text': '28', 'start': 489.219, 'duration': 4.78},
#  {'text': 'there are 28 base 10 blocks the number',
#   'start': 490.759,
#   'duration': 5.791},
#  {'text': "on left let's compare that to number on",
#   'start': 493.999,
#   'duration': 6.0},
#  {'text': 'the right phenom blur on the right has 1',
#   'start': 496.55,
#   'duration': 6.959},
#  {'text': "2 3 4 Long's", 'start': 499.999, 'duration': 6.241},
#  {'text': "I'm already starting to think the number",
#   'start': 503.509,
#   'duration': 3.84},
#  {'text': 'on the right is going to be bigger',
#   'start': 506.24,
#   'duration': 3.209},
#  {'text': 'because it has more logs', 'start': 507.349, 'duration': 5.43},
#  {'text': 'remember the logs are worth 10 each and',
#   'start': 509.449,
#   'duration': 7.851},
#  {'text': "this one has 4 tens that's 10 20 30 40",
#   'start': 512.779,
#   'duration': 8.221},
#  {'text': "so already this has 40 cubes we didn't",
#   'start': 517.3,
#   'duration': 5.71},
#  {'text': "Avenue we haven't even counted on the",
#   'start': 521.0,
#   'duration': 5.389},
#  {'text': 'two cubes yet which gives us 41 and 42',
#   'start': 523.01,
#   'duration': 6.18},
#  {'text': 'so this number is definitely greater',
#   'start': 526.389,
#   'duration': 5.981},
#  {'text': "than 28 now let's check which way the",
#   'start': 529.19,
#   'duration': 5.19},
#  {'text': 'comparison symbols', 'start': 532.37, 'duration': 4.839},
#  {'text': 'in this example the comparison similar',
#   'start': 534.38,
#   'duration': 5.53},
#  {'text': 'shows that the 28 is greater so this is',
#   'start': 537.209,
#   'duration': 6.531},
#  {'text': 'not true we cannot check this is correct',
#   'start': 539.91,
#   'duration': 5.989},
#  {'text': "let's take a look at our next example",
#   'start': 543.74,
#   'duration': 5.26},
#  {'text': "wow there's a lot of longs in this one",
#   'start': 545.899,
#   'duration': 4.99},
#  {'text': "let's see if we can figure out which",
#   'start': 549.0,
#   'duration': 3.99},
#  {'text': 'number is larger by just counting the',
#   'start': 550.889,
#   'duration': 4.111},
#  {'text': "Long's let's count the loggers in the",
#   'start': 552.99,
#   'duration': 10.62},
#  {'text': 'first number we have 1 2 3 4 5 6 7 8',
#   'start': 555.0,
#   'duration': 10.35},
#  {'text': "no it's couple Long's in the other",
#   'start': 563.61,
#   'duration': 10.56},
#  {'text': 'number 1 2 3 4 5 6 7 & 8 so they both',
#   'start': 565.35,
#   'duration': 10.979},
#  {'text': "have eight tens which means they're both",
#   'start': 574.17,
#   'duration': 5.33},
#  {'text': 'equal to 80 let the number on the left',
#   'start': 576.329,
#   'duration': 11.37},
#  {'text': 'also has 1 2 3 4 5 cubes making it 85 81',
#   'start': 579.5,
#   'duration': 14.91},
#  {'text': '82 83 84 and 85 - the number on the left',
#   'start': 587.699,
#   'duration': 11.041},
#  {'text': '85 is largely for the comparison symbol',
#   'start': 594.41,
#   'duration': 7.33},
#  {'text': "shows that 80 is larger and that's not",
#   'start': 598.74,
#   'duration': 3.89},
#  {'text': 'correct', 'start': 601.74, 'duration': 3.36},
#  {'text': "so we can't check this one is correct",
#   'start': 602.63,
#   'duration': 6.24},
#  {'text': "either now let's look at the last row",
#   'start': 605.1,
#   'duration': 5.969},
#  {'text': "again let's count the base 10 blocks",
#   'start': 608.87,
#   'duration': 3.73},
#  {'text': "let's see how many there are in each",
#   'start': 611.069,
#   'duration': 3.901},
#  {'text': "problem let's start with the logs on the",
#   'start': 612.6,
#   'duration': 7.289},
#  {'text': "left there's 1 2 3 4 which means there's",
#   'start': 614.97,
#   'duration': 7.309},
#  {'text': "40 let's count belongs on the right",
#   'start': 619.889,
#   'duration': 8.961},
#  {'text': "here's the 10 20 30 and 40 also for long",
#   'start': 622.279,
#   'duration': 9.221},
#  {'text': "so they both have four Long's", 'start': 628.85, 'duration': 5.98},
#  {'text': "let's count the cubes there's one two",
#   'start': 631.5,
#   'duration': 8.76},
#  {'text': 'three four five six seven so we have',
#   'start': 634.83,
#   'duration': 8.91},
#  {'text': 'forty plus seven twenty one two three',
#   'start': 640.26,
#   'duration': 8.22},
#  {'text': 'four five six seven forty seven on the',
#   'start': 643.74,
#   'duration': 6.6},
#  {'text': "left now let's count the cubes on the",
#   'start': 648.48,
#   'duration': 11.4},
#  {'text': 'right 41 42 43 44 45 46 and 47',
#   'start': 650.34,
#   'duration': 12.26},
#  {'text': 'there are also 47 cubes on the right',
#   'start': 659.88,
#   'duration': 5.55},
#  {'text': 'these numbers are equal to each other',
#   'start': 662.6,
#   'duration': 5.17},
#  {'text': 'can we can see from the comparison',
#   'start': 665.43,
#   'duration': 4.35},
#  {'text': "symbol it's got it correct", 'start': 667.77, 'duration': 4.5},
#  {'text': 'these numbers are people so we can go',
#   'start': 669.78,
#   'duration': 4.98},
#  {'text': 'ahead and check that as correct remember',
#   'start': 672.27,
#   'duration': 5.1},
#  {'text': "boys and girls the Long's are worth 10",
#   'start': 674.76,
#   'duration': 5.22},
#  {'text': 'so you can count by tens to help you',
#   'start': 677.37,
#   'duration': 5.76},
#  {'text': 'prepare numbers easier then look and see',
#   'start': 679.98,
#   'duration': 5.16},
#  {'text': 'if the other number has a greater or',
#   'start': 683.13,
#   'duration': 4.53},
#  {'text': "less than number of tens if they're the",
#   'start': 685.14,
#   'duration': 5.13},
#  {'text': 'same go ahead and count the ones or the',
#   'start': 687.66,
#   'duration': 4.92},
#  {'text': 'cubed to see which number is greater in',
#   'start': 690.27,
#   'duration': 4.38},
#  {'text': 'the end thanks for watching boys and',
#   'start': 692.58,
#   'duration': 5.87},
#  {'text': "girls we'll see you next time alright",
#   'start': 694.65,
#   'duration': 6.48},
#  {'text': "welcome back it's nice to see you again",
#   'start': 698.45,
#   'duration': 5.23},
#  {'text': "what we're gonna do today is we're going",
#   'start': 701.13,
#   'duration': 4.97},
#  {'text': "to be comparing numbers and we've got a",
#   'start': 703.68,
#   'duration': 4.23},
#  {'text': 'thanksgiving-themed worksheet this is',
#   'start': 706.1,
#   'duration': 4.06},
#  {'text': 'gonna be lots of fun the directions say',
#   'start': 707.91,
#   'duration': 5.79},
#  {'text': 'help the turkey find the way out draw a',
#   'start': 710.16,
#   'duration': 5.82},
#  {'text': 'line to connect all the numbers that are',
#   'start': 713.7,
#   'duration': 7.68},
#  {'text': "less than 57 less than 57 okay so let's",
#   'start': 715.98,
#   'duration': 7.59},
#  {'text': "think about this let's come over here to",
#   'start': 721.38,
#   'duration': 4.44},
#  {'text': "the side and let's draw out a number",
#   'start': 723.57,
#   'duration': 5.52},
#  {'text': 'line okay and in the middle of my lumber',
#   'start': 725.82,
#   'duration': 7.5},
#  {'text': "number line I'm gonna put 57 like this",
#   'start': 729.09,
#   'duration': 7.02},
#  {'text': 'okay what would be a number that would',
#   'start': 733.32,
#   'duration': 5.7},
#  {'text': 'be the next number up than 57 that would',
#   'start': 736.11,
#   'duration': 6.32},
#  {'text': 'be greater than 57', 'start': 739.02, 'duration': 9.92},
#  {'text': "that'd be that would be 57 58 59 okay 60",
#   'start': 742.43,
#   'duration': 8.79},
#  {'text': 'those would all be examples of numbers',
#   'start': 748.94,
#   'duration': 6.03},
#  {'text': "that are greater than right but we're",
#   'start': 751.22,
#   'duration': 5.809},
#  {'text': 'looking for numbers that are less than',
#   'start': 754.97,
#   'duration': 5.869},
#  {'text': 'so we need any number below', 'start': 757.029, 'duration': 12.821},
#  {'text': '57 like for example 56 55 54 53 all the',
#   'start': 760.839,
#   'duration': 12.161},
#  {'text': 'way down to zero right and all the',
#   'start': 769.85,
#   'duration': 4.89},
#  {'text': 'numbers that are in between that so',
#   'start': 773.0,
#   'duration': 3.209},
#  {'text': "we're looking for all the numbers on",
#   'start': 774.74,
#   'duration': 4.289},
#  {'text': 'this side of the number line that are',
#   'start': 776.209,
#   'duration': 6.931},
#  {'text': "less than 57 okay so let's think for a",
#   'start': 779.029,
#   'duration': 6.991},
#  {'text': "minute about where we're gonna go let's",
#   'start': 783.14,
#   'duration': 4.86},
#  {'text': "start at the turkey okay and he's trying",
#   'start': 786.02,
#   'duration': 3.18},
#  {'text': 'to find his way out', 'start': 788.0, 'duration': 4.589},
#  {'text': "so let's come on out okay and let's see",
#   'start': 789.2,
#   'duration': 4.74},
#  {'text': 'which direction to go', 'start': 792.589, 'duration': 6.031},
#  {'text': 'now do we go to the 18 or the 77 is 77',
#   'start': 793.94,
#   'duration': 9.51},
#  {'text': "less than 57 no it's greater than 57",
#   'start': 798.62,
#   'duration': 7.83},
#  {'text': "it's bigger than 57 so let's look at",
#   'start': 803.45,
#   'duration': 5.28},
#  {'text': 'this one what about 18 if that less than',
#   'start': 806.45,
#   'duration': 5.25},
#  {'text': "57 yeah so we're gonna go down to this",
#   'start': 808.73,
#   'duration': 5.4},
#  {'text': 'one right here it would be 18 would be',
#   'start': 811.7,
#   'duration': 4.38},
#  {'text': 'on this side of the number line',
#   'start': 814.13,
#   'duration': 5.85},
#  {'text': "okay so let's go on Dion and let's look",
#   'start': 816.08,
#   'duration': 6.36},
#  {'text': 'the next one we next direction we can go',
#   'start': 819.98,
#   'duration': 6.42},
#  {'text': 'is either 99 or 21 which one is less',
#   'start': 822.44,
#   'duration': 9.24},
#  {'text': "than 57 and 99 well that's too big 21",
#   'start': 826.4,
#   'duration': 8.37},
#  {'text': "yep that's smaller than 57 so we're",
#   'start': 831.68,
#   'duration': 5.52},
#  {'text': "gonna go around this way okay that's",
#   'start': 834.77,
#   'duration': 5.55},
#  {'text': 'less than 57 now we can either go to 58',
#   'start': 837.2,
#   'duration': 7.23},
#  {'text': "or 2/3 which one is less than 57 don't",
#   'start': 840.32,
#   'duration': 8.4},
#  {'text': 'get confused here 3 is less than 57 58',
#   'start': 844.43,
#   'duration': 6.48},
#  {'text': 'is on this side of the number line you',
#   'start': 848.72,
#   'duration': 4.23},
#  {'text': "remember we don't want to go that way so",
#   'start': 850.91,
#   'duration': 5.13},
#  {'text': "we're gonna go up to 3 okay and then",
#   'start': 852.95,
#   'duration': 3.24},
#  {'text': "we're", 'start': 856.04, 'duration': 2.88},
#  {'text': 'come through here and right through here',
#   'start': 856.19,
#   'duration': 3.9},
#  {'text': "and then we've got a couple of choices",
#   'start': 858.92,
#   'duration': 5.94},
#  {'text': 'we can either go to 60 or 56 which one',
#   'start': 860.09,
#   'duration': 10.2},
#  {'text': 'is going to be less than 57 56 is less',
#   'start': 864.86,
#   'duration': 7.38},
#  {'text': "than 57 it's even on our number line",
#   'start': 870.29,
#   'duration': 4.77},
#  {'text': "they'll be true 60 is more than or",
#   'start': 872.24,
#   'duration': 5.93},
#  {'text': "greater than so we're going to go to 56",
#   'start': 875.06,
#   'duration': 5.79},
#  {'text': "okay and then let's keep going around",
#   'start': 878.17,
#   'duration': 8.41},
#  {'text': 'here we can either go to 10 or 67 so 10',
#   'start': 880.85,
#   'duration': 8.22},
#  {'text': "is less than so we're going to go this",
#   'start': 886.58,
#   'duration': 4.95},
#  {'text': "way and then we're gonna keep going",
#   'start': 889.07,
#   'duration': 4.98},
#  {'text': "around you're doing so good and then",
#   'start': 891.53,
#   'duration': 6.0},
#  {'text': "we've got two more choices we've got 57",
#   'start': 894.05,
#   'duration': 6.93},
#  {'text': "or 31 now this one's a little bit tricky",
#   'start': 897.53,
#   'duration': 5.4},
#  {'text': "I didn't talk about this we're looking",
#   'start': 900.98,
#   'duration': 5.85},
#  {'text': 'for numbers that are less than 57 is 57',
#   'start': 902.93,
#   'duration': 8.37},
#  {'text': "less than 57 no it's actually equals 2",
#   'start': 906.83,
#   'duration': 6.66},
#  {'text': "that means the same as so that's not",
#   'start': 911.3,
#   'duration': 3.87},
#  {'text': 'where we need to go we need to go less',
#   'start': 913.49,
#   'duration': 4.05},
#  {'text': 'than this way so our other choice here',
#   'start': 915.17,
#   'duration': 5.16},
#  {'text': 'is 31 31 would be on this side in the',
#   'start': 917.54,
#   'duration': 7.17},
#  {'text': "number line so we're gonna go to 31 look",
#   'start': 920.33,
#   'duration': 6.63},
#  {'text': 'at that we made our way out we got our',
#   'start': 924.71,
#   'duration': 3.96},
#  {'text': "turkey out of our maze didn't we",
#   'start': 926.96,
#   'duration': 5.94},
#  {'text': 'great job today subscribe to our channel',
#   'start': 928.67,
#   'duration': 7.77},
#  {'text': 'to stay updated on new videos find links',
#   'start': 932.9,
#   'duration': 7.13},
#  {'text': 'to our apps in the comments below',
#   'start': 936.44,
#   'duration': 3.59}]

# %%
filtered_transcript = list(filter(lambda e: e['text'] != '[Music]', raw_transcript))

# %%
filtered_transcript
# Out:
# [{'text': 'hello boys and girls we are at the',
#   'start': 12.06,
#   'duration': 6.55},
#  {'text': 'racetrack ready to compare some numbers',
#   'start': 15.7,
#   'duration': 6.15},
#  {'text': "let's see which cars participate in the",
#   'start': 18.61,
#   'duration': 5.64},
#  {'text': 'race today and which numbers we are',
#   'start': 21.85,
#   'duration': 4.98},
#  {'text': 'going to compare you already know about',
#   'start': 24.25,
#   'duration': 5.4},
#  {'text': 'place value and compare numbers using',
#   'start': 26.83,
#   'duration': 6.42},
#  {'text': "base ten blocks now I'll help you find",
#   'start': 29.65,
#   'duration': 5.85},
#  {'text': 'numbers that are greater than or less',
#   'start': 33.25,
#   'duration': 6.36},
#  {'text': 'than other numbers on your mark get set',
#   'start': 35.5,
#   'duration': 8.79},
#  {'text': 'go do you like that racing helmet see',
#   'start': 39.61,
#   'duration': 9.06},
#  {'text': "the number it's number 25 we can look at",
#   'start': 44.29,
#   'duration': 7.38},
#  {'text': 'the digit in the tens place first to',
#   'start': 48.67,
#   'duration': 5.88},
#  {'text': 'help compare numbers how many tens does',
#   'start': 51.67,
#   'duration': 7.889},
#  {'text': 'my number have 25 has two tens', 'start': 54.55, 'duration': 11.7},
#  {'text': "it also has five ones nice job there's",
#   'start': 59.559,
#   'duration': 9.721},
#  {'text': 'one of the race cars now what number is',
#   'start': 66.25,
#   'duration': 10.5},
#  {'text': 'it is 31 greater or less than 25 both 25',
#   'start': 69.28,
#   'duration': 10.26},
#  {'text': 'and 31 have numbers in the tens place',
#   'start': 76.75,
#   'duration': 7.77},
#  {'text': 'see we see that 3 is greater than 2 that',
#   'start': 79.54,
#   'duration': 9.81},
#  {'text': 'means that 31 is greater than 25 we put',
#   'start': 84.52,
#   'duration': 7.2},
#  {'text': 'up the greater than sign with this small',
#   'start': 89.35,
#   'duration': 5.01},
#  {'text': 'pointed side chasing the smaller number',
#   'start': 91.72,
#   'duration': 8.64},
#  {'text': 'so the sign would look like this whoa',
#   'start': 94.36,
#   'duration': 8.579},
#  {'text': "look there's another car with a new",
#   'start': 100.36,
#   'duration': 6.41},
#  {'text': 'number is that number greater than 25',
#   'start': 102.939,
#   'duration': 6.871},
#  {'text': 'well first we can look at the largest',
#   'start': 106.77,
#   'duration': 5.26},
#  {'text': 'place which are the numbers on the far',
#   'start': 109.81,
#   'duration': 5.72},
#  {'text': "left they are the same they're both two",
#   'start': 112.03,
#   'duration': 7.229},
#  {'text': "that's ok if the tens place is the same",
#   'start': 115.53,
#   'duration': 5.83},
#  {'text': 'and then we can just compare the ones',
#   'start': 119.259,
#   'duration': 6.091},
#  {'text': 'place see we can compare using place',
#   'start': 121.36,
#   'duration': 5.22},
#  {'text': 'value', 'start': 125.35, 'duration': 5.64},
#  {'text': 'I can hear some cars getting ready to',
#   'start': 126.58,
#   'duration': 4.92},
#  {'text': 'race', 'start': 130.99, 'duration': 5.25},
#  {'text': "let's compare their numbers do you",
#   'start': 131.5,
#   'duration': 8.27},
#  {'text': 'remember where we start when we compare',
#   'start': 136.24,
#   'duration': 6.18},
#  {'text': 'they both have fours and fives in their',
#   'start': 139.77,
#   'duration': 6.01},
#  {'text': 'number but but one with the five in the',
#   'start': 142.42,
#   'duration': 6.69},
#  {'text': "tens place has a greater value that's",
#   'start': 145.78,
#   'duration': 5.07},
#  {'text': 'why we should always start at the left',
#   'start': 149.11,
#   'duration': 5.58},
#  {'text': 'with the largest place 54 is greater',
#   'start': 150.85,
#   'duration': 7.92},
#  {'text': 'than 45 that also means that 45 is less',
#   'start': 154.69,
#   'duration': 7.83},
#  {'text': 'than 54 do you see another number that',
#   'start': 158.77,
#   'duration': 11.37},
#  {'text': 'is less than 54 yes 25 is less than 54',
#   'start': 162.52,
#   'duration': 11.85},
#  {'text': "it's less than 45 too because number 25",
#   'start': 170.14,
#   'duration': 8.48},
#  {'text': 'only has a 2 in the tens place', 'start': 174.37, 'duration': 4.25},
#  {'text': 'there are 2 more cars are the numbers',
#   'start': 180.27,
#   'duration': 9.55},
#  {'text': 'greater than or less than 25 it looks',
#   'start': 184.18,
#   'duration': 7.26},
#  {'text': 'like they both have bigger numbers in',
#   'start': 189.82,
#   'duration': 3.96},
#  {'text': 'the tens place so they are both greater',
#   'start': 191.44,
#   'duration': 8.61},
#  {'text': 'than 25 remember look left and compare',
#   'start': 193.78,
#   'duration': 9.26},
#  {'text': 'the tens place first', 'start': 200.05, 'duration': 2.99},
#  {'text': 'on your mark get set go', 'start': 203.36, 'duration': 4.83},
#  {'text': 'thanks for watching boys and girls see',
#   'start': 208.58,
#   'duration': 5.31},
#  {'text': 'you next time', 'start': 211.319, 'duration': 2.571},
#  {'text': 'hello boys and girls', 'start': 216.019, 'duration': 3.911},
#  {'text': "it's teacher Mike here and today we're",
#   'start': 217.739,
#   'duration': 3.601},
#  {'text': 'going to be looking at a worksheet that',
#   'start': 219.93,
#   'duration': 4.529},
#  {'text': 'axe us to compare numbers before we get',
#   'start': 221.34,
#   'duration': 5.25},
#  {'text': "started let's remind ourselves to some",
#   'start': 224.459,
#   'duration': 3.721},
#  {'text': 'really important things to know and',
#   'start': 226.59,
#   'duration': 6.6},
#  {'text': 'place value first which base 10 block',
#   'start': 228.18,
#   'duration': 8.46},
#  {'text': 'that you see this is a cube do you know',
#   'start': 233.19,
#   'duration': 6.12},
#  {'text': 'the value of the cube cube is worth just',
#   'start': 236.64,
#   'duration': 6.27},
#  {'text': 'one how about a long you know how much',
#   'start': 239.31,
#   'duration': 6.989},
#  {'text': 'the long is worth well the long is made',
#   'start': 242.91,
#   'duration': 6.51},
#  {'text': 'up of ten individual cubes and therefore',
#   'start': 246.299,
#   'duration': 6.871},
#  {'text': "the long is worth ten let's use this",
#   'start': 249.42,
#   'duration': 5.97},
#  {'text': 'information tell us to compare numbers',
#   'start': 253.17,
#   'duration': 6.33},
#  {'text': "with base ten blocks let's say for",
#   'start': 255.39,
#   'duration': 6.54},
#  {'text': "example we had a number with two Long's",
#   'start': 259.5,
#   'duration': 5.55},
#  {'text': 'and two cubes we wanted to compare this',
#   'start': 261.93,
#   'duration': 5.7},
#  {'text': 'to a number with one long and three',
#   'start': 265.05,
#   'duration': 5.76},
#  {'text': 'cubes well one of these blocks really',
#   'start': 267.63,
#   'duration': 6.06},
#  {'text': 'represent one way we can see what this',
#   'start': 270.81,
#   'duration': 5.37},
#  {'text': 'number is quickly by simply counting the',
#   'start': 273.69,
#   'duration': 5.13},
#  {'text': "base ten blocks starting with the Long's",
#   'start': 276.18,
#   'duration': 5.94},
#  {'text': "so let's give it a shot in this number",
#   'start': 278.82,
#   'duration': 5.31},
#  {'text': "we have one long and that's representing",
#   'start': 282.12,
#   'duration': 4.41},
#  {'text': 'ten and another long and that represents',
#   'start': 284.13,
#   'duration': 5.3},
#  {'text': 'ten so we can count by 10 two times',
#   'start': 286.53,
#   'duration': 7.59},
#  {'text': "let's give it a shot 10 20 now we know",
#   'start': 289.43,
#   'duration': 7.81},
#  {'text': 'we have 20 we can just count on with our',
#   'start': 294.12,
#   'duration': 7.109},
#  {'text': 'other two cubes and represent ones 20 21',
#   'start': 297.24,
#   'duration': 7.64},
#  {'text': '22 so I know that these base 10 blocks',
#   'start': 301.229,
#   'duration': 7.311},
#  {'text': 'represent the number 22 well', 'start': 304.88, 'duration': 6.12},
#  {'text': 'about the number on the right side this',
#   'start': 308.54,
#   'duration': 6.27},
#  {'text': "side I see 110 already I'm starting to",
#   'start': 311.0,
#   'duration': 6.93},
#  {'text': "think if there's only 110 in this number",
#   'start': 314.81,
#   'duration': 6.56},
#  {'text': "it's probably smaller or less than 22",
#   'start': 317.93,
#   'duration': 6.39},
#  {'text': "let's count all the base ten blocks just",
#   'start': 321.37,
#   'duration': 6.37},
#  {'text': 'to be sure after ten we can just count',
#   'start': 324.32,
#   'duration': 7.47},
#  {'text': 'on our three cubes ten eleven twelve',
#   'start': 327.74,
#   'duration': 8.64},
#  {'text': 'thirteen so we know that 22 is greater',
#   'start': 331.79,
#   'duration': 6.96},
#  {'text': "than 13 so we'll draw the comparison",
#   'start': 336.38,
#   'duration': 5.01},
#  {'text': 'symbol with the mouth open towards the',
#   'start': 338.75,
#   'duration': 4.74},
#  {'text': 'bigger number because you will always',
#   'start': 341.39,
#   'duration': 5.97},
#  {'text': "eat the bigger number let's get started",
#   'start': 343.49,
#   'duration': 5.79},
#  {'text': "with our worksheet let's read the",
#   'start': 347.36,
#   'duration': 4.28},
#  {'text': 'directions start with the first problem',
#   'start': 349.28,
#   'duration': 6.27},
#  {'text': 'comparing numbers base ten blocks count',
#   'start': 351.64,
#   'duration': 7.39},
#  {'text': 'tens and ones in each pair and compare',
#   'start': 355.55,
#   'duration': 5.73},
#  {'text': 'the numbers check the pairs where the',
#   'start': 359.03,
#   'duration': 6.06},
#  {'text': 'signs of comparison are correct okay we',
#   'start': 361.28,
#   'duration': 5.28},
#  {'text': 'have a nice little reminder up top',
#   'start': 365.09,
#   'duration': 3.84},
#  {'text': 'reminding us about the lungs or worth',
#   'start': 366.56,
#   'duration': 5.82},
#  {'text': "Tim and the cubes are worth one so let's",
#   'start': 368.93,
#   'duration': 4.92},
#  {'text': 'get started by counting the base ten',
#   'start': 372.38,
#   'duration': 4.23},
#  {'text': 'blocks remember we can count by tens if',
#   'start': 373.85,
#   'duration': 5.73},
#  {'text': "we see it long so let's look at our",
#   'start': 376.61,
#   'duration': 5.73},
#  {'text': "first picture how many Long's are there",
#   'start': 379.58,
#   'duration': 7.47},
#  {'text': "called I see one two three four Long's",
#   'start': 382.34,
#   'duration': 8.22},
#  {'text': "hello that's worth 40 now let's see how",
#   'start': 387.05,
#   'duration': 7.32},
#  {'text': "many cubes we have there's one two three",
#   'start': 390.56,
#   'duration': 7.95},
#  {'text': "four five cubes so let's count home from",
#   'start': 394.37,
#   'duration': 12.21},
#  {'text': 'forty five more 41 42 43 44 45 our first',
#   'start': 398.51,
#   'duration': 11.91},
#  {'text': "number has 45 let's compare it to the",
#   'start': 406.58,
#   'duration': 5.429},
#  {'text': 'number on the right', 'start': 410.42, 'duration': 4.139},
#  {'text': 'we can first start by counting how many',
#   'start': 412.009,
#   'duration': 6.27},
#  {'text': 'logs there well miss number we feared',
#   'start': 414.559,
#   'duration': 11.491},
#  {'text': "there's one two three four five logs do",
#   'start': 418.279,
#   'duration': 9.87},
#  {'text': "think this number with five Long's or",
#   'start': 426.05,
#   'duration': 4.41},
#  {'text': "five tens it's going to be greater or",
#   'start': 428.149,
#   'duration': 4.95},
#  {'text': 'less than forty five how much is five',
#   'start': 430.46,
#   'duration': 5.039},
#  {'text': "tens really work let's just count the",
#   'start': 433.099,
#   'duration': 8.79},
#  {'text': 'tens 10 20 30 40 and 50 so already',
#   'start': 435.499,
#   'duration': 9.241},
#  {'text': "that's greater than 45 let's count the",
#   'start': 441.889,
#   'duration': 4.881},
#  {'text': 'cubes just so we can get a final count',
#   'start': 444.74,
#   'duration': 6.679},
#  {'text': '51 52 53 54', 'start': 446.77, 'duration': 9.28},
#  {'text': "so 54 is greater than 45 let's see if it",
#   'start': 451.419,
#   'duration': 6.31},
#  {'text': 'ends Paris and simple is facing the',
#   'start': 456.05,
#   'duration': 5.519},
#  {'text': 'right way it is the symbol is eating the',
#   'start': 457.729,
#   'duration': 7.23},
#  {'text': '54 so we know this is correct we can go',
#   'start': 461.569,
#   'duration': 5.88},
#  {'text': "ahead and check the box let's take a",
#   'start': 464.959,
#   'duration': 6.121},
#  {'text': 'look at our next example in this problem',
#   'start': 467.449,
#   'duration': 5.911},
#  {'text': 'on the number on the Left we have two',
#   'start': 471.08,
#   'duration': 6.359},
#  {'text': "tens we know that equals 20 let's see",
#   'start': 473.36,
#   'duration': 7.109},
#  {'text': "how many ones we have in let's count",
#   'start': 477.439,
#   'duration': 11.78},
#  {'text': 'from 20 we have 21 22 23 and 24 25 26 27',
#   'start': 480.469,
#   'duration': 10.29},
#  {'text': '28', 'start': 489.219, 'duration': 4.78},
#  {'text': 'there are 28 base 10 blocks the number',
#   'start': 490.759,
#   'duration': 5.791},
#  {'text': "on left let's compare that to number on",
#   'start': 493.999,
#   'duration': 6.0},
#  {'text': 'the right phenom blur on the right has 1',
#   'start': 496.55,
#   'duration': 6.959},
#  {'text': "2 3 4 Long's", 'start': 499.999, 'duration': 6.241},
#  {'text': "I'm already starting to think the number",
#   'start': 503.509,
#   'duration': 3.84},
#  {'text': 'on the right is going to be bigger',
#   'start': 506.24,
#   'duration': 3.209},
#  {'text': 'because it has more logs', 'start': 507.349, 'duration': 5.43},
#  {'text': 'remember the logs are worth 10 each and',
#   'start': 509.449,
#   'duration': 7.851},
#  {'text': "this one has 4 tens that's 10 20 30 40",
#   'start': 512.779,
#   'duration': 8.221},
#  {'text': "so already this has 40 cubes we didn't",
#   'start': 517.3,
#   'duration': 5.71},
#  {'text': "Avenue we haven't even counted on the",
#   'start': 521.0,
#   'duration': 5.389},
#  {'text': 'two cubes yet which gives us 41 and 42',
#   'start': 523.01,
#   'duration': 6.18},
#  {'text': 'so this number is definitely greater',
#   'start': 526.389,
#   'duration': 5.981},
#  {'text': "than 28 now let's check which way the",
#   'start': 529.19,
#   'duration': 5.19},
#  {'text': 'comparison symbols', 'start': 532.37, 'duration': 4.839},
#  {'text': 'in this example the comparison similar',
#   'start': 534.38,
#   'duration': 5.53},
#  {'text': 'shows that the 28 is greater so this is',
#   'start': 537.209,
#   'duration': 6.531},
#  {'text': 'not true we cannot check this is correct',
#   'start': 539.91,
#   'duration': 5.989},
#  {'text': "let's take a look at our next example",
#   'start': 543.74,
#   'duration': 5.26},
#  {'text': "wow there's a lot of longs in this one",
#   'start': 545.899,
#   'duration': 4.99},
#  {'text': "let's see if we can figure out which",
#   'start': 549.0,
#   'duration': 3.99},
#  {'text': 'number is larger by just counting the',
#   'start': 550.889,
#   'duration': 4.111},
#  {'text': "Long's let's count the loggers in the",
#   'start': 552.99,
#   'duration': 10.62},
#  {'text': 'first number we have 1 2 3 4 5 6 7 8',
#   'start': 555.0,
#   'duration': 10.35},
#  {'text': "no it's couple Long's in the other",
#   'start': 563.61,
#   'duration': 10.56},
#  {'text': 'number 1 2 3 4 5 6 7 & 8 so they both',
#   'start': 565.35,
#   'duration': 10.979},
#  {'text': "have eight tens which means they're both",
#   'start': 574.17,
#   'duration': 5.33},
#  {'text': 'equal to 80 let the number on the left',
#   'start': 576.329,
#   'duration': 11.37},
#  {'text': 'also has 1 2 3 4 5 cubes making it 85 81',
#   'start': 579.5,
#   'duration': 14.91},
#  {'text': '82 83 84 and 85 - the number on the left',
#   'start': 587.699,
#   'duration': 11.041},
#  {'text': '85 is largely for the comparison symbol',
#   'start': 594.41,
#   'duration': 7.33},
#  {'text': "shows that 80 is larger and that's not",
#   'start': 598.74,
#   'duration': 3.89},
#  {'text': 'correct', 'start': 601.74, 'duration': 3.36},
#  {'text': "so we can't check this one is correct",
#   'start': 602.63,
#   'duration': 6.24},
#  {'text': "either now let's look at the last row",
#   'start': 605.1,
#   'duration': 5.969},
#  {'text': "again let's count the base 10 blocks",
#   'start': 608.87,
#   'duration': 3.73},
#  {'text': "let's see how many there are in each",
#   'start': 611.069,
#   'duration': 3.901},
#  {'text': "problem let's start with the logs on the",
#   'start': 612.6,
#   'duration': 7.289},
#  {'text': "left there's 1 2 3 4 which means there's",
#   'start': 614.97,
#   'duration': 7.309},
#  {'text': "40 let's count belongs on the right",
#   'start': 619.889,
#   'duration': 8.961},
#  {'text': "here's the 10 20 30 and 40 also for long",
#   'start': 622.279,
#   'duration': 9.221},
#  {'text': "so they both have four Long's", 'start': 628.85, 'duration': 5.98},
#  {'text': "let's count the cubes there's one two",
#   'start': 631.5,
#   'duration': 8.76},
#  {'text': 'three four five six seven so we have',
#   'start': 634.83,
#   'duration': 8.91},
#  {'text': 'forty plus seven twenty one two three',
#   'start': 640.26,
#   'duration': 8.22},
#  {'text': 'four five six seven forty seven on the',
#   'start': 643.74,
#   'duration': 6.6},
#  {'text': "left now let's count the cubes on the",
#   'start': 648.48,
#   'duration': 11.4},
#  {'text': 'right 41 42 43 44 45 46 and 47',
#   'start': 650.34,
#   'duration': 12.26},
#  {'text': 'there are also 47 cubes on the right',
#   'start': 659.88,
#   'duration': 5.55},
#  {'text': 'these numbers are equal to each other',
#   'start': 662.6,
#   'duration': 5.17},
#  {'text': 'can we can see from the comparison',
#   'start': 665.43,
#   'duration': 4.35},
#  {'text': "symbol it's got it correct", 'start': 667.77, 'duration': 4.5},
#  {'text': 'these numbers are people so we can go',
#   'start': 669.78,
#   'duration': 4.98},
#  {'text': 'ahead and check that as correct remember',
#   'start': 672.27,
#   'duration': 5.1},
#  {'text': "boys and girls the Long's are worth 10",
#   'start': 674.76,
#   'duration': 5.22},
#  {'text': 'so you can count by tens to help you',
#   'start': 677.37,
#   'duration': 5.76},
#  {'text': 'prepare numbers easier then look and see',
#   'start': 679.98,
#   'duration': 5.16},
#  {'text': 'if the other number has a greater or',
#   'start': 683.13,
#   'duration': 4.53},
#  {'text': "less than number of tens if they're the",
#   'start': 685.14,
#   'duration': 5.13},
#  {'text': 'same go ahead and count the ones or the',
#   'start': 687.66,
#   'duration': 4.92},
#  {'text': 'cubed to see which number is greater in',
#   'start': 690.27,
#   'duration': 4.38},
#  {'text': 'the end thanks for watching boys and',
#   'start': 692.58,
#   'duration': 5.87},
#  {'text': "girls we'll see you next time alright",
#   'start': 694.65,
#   'duration': 6.48},
#  {'text': "welcome back it's nice to see you again",
#   'start': 698.45,
#   'duration': 5.23},
#  {'text': "what we're gonna do today is we're going",
#   'start': 701.13,
#   'duration': 4.97},
#  {'text': "to be comparing numbers and we've got a",
#   'start': 703.68,
#   'duration': 4.23},
#  {'text': 'thanksgiving-themed worksheet this is',
#   'start': 706.1,
#   'duration': 4.06},
#  {'text': 'gonna be lots of fun the directions say',
#   'start': 707.91,
#   'duration': 5.79},
#  {'text': 'help the turkey find the way out draw a',
#   'start': 710.16,
#   'duration': 5.82},
#  {'text': 'line to connect all the numbers that are',
#   'start': 713.7,
#   'duration': 7.68},
#  {'text': "less than 57 less than 57 okay so let's",
#   'start': 715.98,
#   'duration': 7.59},
#  {'text': "think about this let's come over here to",
#   'start': 721.38,
#   'duration': 4.44},
#  {'text': "the side and let's draw out a number",
#   'start': 723.57,
#   'duration': 5.52},
#  {'text': 'line okay and in the middle of my lumber',
#   'start': 725.82,
#   'duration': 7.5},
#  {'text': "number line I'm gonna put 57 like this",
#   'start': 729.09,
#   'duration': 7.02},
#  {'text': 'okay what would be a number that would',
#   'start': 733.32,
#   'duration': 5.7},
#  {'text': 'be the next number up than 57 that would',
#   'start': 736.11,
#   'duration': 6.32},
#  {'text': 'be greater than 57', 'start': 739.02, 'duration': 9.92},
#  {'text': "that'd be that would be 57 58 59 okay 60",
#   'start': 742.43,
#   'duration': 8.79},
#  {'text': 'those would all be examples of numbers',
#   'start': 748.94,
#   'duration': 6.03},
#  {'text': "that are greater than right but we're",
#   'start': 751.22,
#   'duration': 5.809},
#  {'text': 'looking for numbers that are less than',
#   'start': 754.97,
#   'duration': 5.869},
#  {'text': 'so we need any number below', 'start': 757.029, 'duration': 12.821},
#  {'text': '57 like for example 56 55 54 53 all the',
#   'start': 760.839,
#   'duration': 12.161},
#  {'text': 'way down to zero right and all the',
#   'start': 769.85,
#   'duration': 4.89},
#  {'text': 'numbers that are in between that so',
#   'start': 773.0,
#   'duration': 3.209},
#  {'text': "we're looking for all the numbers on",
#   'start': 774.74,
#   'duration': 4.289},
#  {'text': 'this side of the number line that are',
#   'start': 776.209,
#   'duration': 6.931},
#  {'text': "less than 57 okay so let's think for a",
#   'start': 779.029,
#   'duration': 6.991},
#  {'text': "minute about where we're gonna go let's",
#   'start': 783.14,
#   'duration': 4.86},
#  {'text': "start at the turkey okay and he's trying",
#   'start': 786.02,
#   'duration': 3.18},
#  {'text': 'to find his way out', 'start': 788.0, 'duration': 4.589},
#  {'text': "so let's come on out okay and let's see",
#   'start': 789.2,
#   'duration': 4.74},
#  {'text': 'which direction to go', 'start': 792.589, 'duration': 6.031},
#  {'text': 'now do we go to the 18 or the 77 is 77',
#   'start': 793.94,
#   'duration': 9.51},
#  {'text': "less than 57 no it's greater than 57",
#   'start': 798.62,
#   'duration': 7.83},
#  {'text': "it's bigger than 57 so let's look at",
#   'start': 803.45,
#   'duration': 5.28},
#  {'text': 'this one what about 18 if that less than',
#   'start': 806.45,
#   'duration': 5.25},
#  {'text': "57 yeah so we're gonna go down to this",
#   'start': 808.73,
#   'duration': 5.4},
#  {'text': 'one right here it would be 18 would be',
#   'start': 811.7,
#   'duration': 4.38},
#  {'text': 'on this side of the number line',
#   'start': 814.13,
#   'duration': 5.85},
#  {'text': "okay so let's go on Dion and let's look",
#   'start': 816.08,
#   'duration': 6.36},
#  {'text': 'the next one we next direction we can go',
#   'start': 819.98,
#   'duration': 6.42},
#  {'text': 'is either 99 or 21 which one is less',
#   'start': 822.44,
#   'duration': 9.24},
#  {'text': "than 57 and 99 well that's too big 21",
#   'start': 826.4,
#   'duration': 8.37},
#  {'text': "yep that's smaller than 57 so we're",
#   'start': 831.68,
#   'duration': 5.52},
#  {'text': "gonna go around this way okay that's",
#   'start': 834.77,
#   'duration': 5.55},
#  {'text': 'less than 57 now we can either go to 58',
#   'start': 837.2,
#   'duration': 7.23},
#  {'text': "or 2/3 which one is less than 57 don't",
#   'start': 840.32,
#   'duration': 8.4},
#  {'text': 'get confused here 3 is less than 57 58',
#   'start': 844.43,
#   'duration': 6.48},
#  {'text': 'is on this side of the number line you',
#   'start': 848.72,
#   'duration': 4.23},
#  {'text': "remember we don't want to go that way so",
#   'start': 850.91,
#   'duration': 5.13},
#  {'text': "we're gonna go up to 3 okay and then",
#   'start': 852.95,
#   'duration': 3.24},
#  {'text': "we're", 'start': 856.04, 'duration': 2.88},
#  {'text': 'come through here and right through here',
#   'start': 856.19,
#   'duration': 3.9},
#  {'text': "and then we've got a couple of choices",
#   'start': 858.92,
#   'duration': 5.94},
#  {'text': 'we can either go to 60 or 56 which one',
#   'start': 860.09,
#   'duration': 10.2},
#  {'text': 'is going to be less than 57 56 is less',
#   'start': 864.86,
#   'duration': 7.38},
#  {'text': "than 57 it's even on our number line",
#   'start': 870.29,
#   'duration': 4.77},
#  {'text': "they'll be true 60 is more than or",
#   'start': 872.24,
#   'duration': 5.93},
#  {'text': "greater than so we're going to go to 56",
#   'start': 875.06,
#   'duration': 5.79},
#  {'text': "okay and then let's keep going around",
#   'start': 878.17,
#   'duration': 8.41},
#  {'text': 'here we can either go to 10 or 67 so 10',
#   'start': 880.85,
#   'duration': 8.22},
#  {'text': "is less than so we're going to go this",
#   'start': 886.58,
#   'duration': 4.95},
#  {'text': "way and then we're gonna keep going",
#   'start': 889.07,
#   'duration': 4.98},
#  {'text': "around you're doing so good and then",
#   'start': 891.53,
#   'duration': 6.0},
#  {'text': "we've got two more choices we've got 57",
#   'start': 894.05,
#   'duration': 6.93},
#  {'text': "or 31 now this one's a little bit tricky",
#   'start': 897.53,
#   'duration': 5.4},
#  {'text': "I didn't talk about this we're looking",
#   'start': 900.98,
#   'duration': 5.85},
#  {'text': 'for numbers that are less than 57 is 57',
#   'start': 902.93,
#   'duration': 8.37},
#  {'text': "less than 57 no it's actually equals 2",
#   'start': 906.83,
#   'duration': 6.66},
#  {'text': "that means the same as so that's not",
#   'start': 911.3,
#   'duration': 3.87},
#  {'text': 'where we need to go we need to go less',
#   'start': 913.49,
#   'duration': 4.05},
#  {'text': 'than this way so our other choice here',
#   'start': 915.17,
#   'duration': 5.16},
#  {'text': 'is 31 31 would be on this side in the',
#   'start': 917.54,
#   'duration': 7.17},
#  {'text': "number line so we're gonna go to 31 look",
#   'start': 920.33,
#   'duration': 6.63},
#  {'text': 'at that we made our way out we got our',
#   'start': 924.71,
#   'duration': 3.96},
#  {'text': "turkey out of our maze didn't we",
#   'start': 926.96,
#   'duration': 5.94},
#  {'text': 'great job today subscribe to our channel',
#   'start': 928.67,
#   'duration': 7.77},
#  {'text': 'to stay updated on new videos find links',
#   'start': 932.9,
#   'duration': 7.13},
#  {'text': 'to our apps in the comments below',
#   'start': 936.44,
#   'duration': 3.59}]

# %%
whole_transcript = list(map(lambda e: e['text'], filtered_transcript))

# %%
docs = " ".join(whole_transcript)

# %%
docs
# Out:
# "hello boys and girls we are at the racetrack ready to compare some numbers let's see which cars participate in the race today and which numbers we are going to compare you already know about place value and compare numbers using base ten blocks now I'll help you find numbers that are greater than or less than other numbers on your mark get set go do you like that racing helmet see the number it's number 25 we can look at the digit in the tens place first to help compare numbers how many tens does my number have 25 has two tens it also has five ones nice job there's one of the race cars now what number is it is 31 greater or less than 25 both 25 and 31 have numbers in the tens place see we see that 3 is greater than 2 that means that 31 is greater than 25 we put up the greater than sign with this small pointed side chasing the smaller number so the sign would look like this whoa look there's another car with a new number is that number greater than 25 well first we can look at the largest place which are the numbers on the far left they are the same they're both two that's ok if the tens place is the same and then we can just compare the ones place see we can compare using place value I can hear some cars getting ready to race let's compare their numbers do you remember where we start when we compare they both have fours and fives in their number but but one with the five in the tens place has a greater value that's why we should always start at the left with the largest place 54 is greater than 45 that also means that 45 is less than 54 do you see another number that is less than 54 yes 25 is less than 54 it's less than 45 too because number 25 only has a 2 in the tens place there are 2 more cars are the numbers greater than or less than 25 it looks like they both have bigger numbers in the tens place so they are both greater than 25 remember look left and compare the tens place first on your mark get set go thanks for watching boys and girls see you next time hello boys and girls it's teacher Mike here and today we're going to be looking at a worksheet that axe us to compare numbers before we get started let's remind ourselves to some really important things to know and place value first which base 10 block that you see this is a cube do you know the value of the cube cube is worth just one how about a long you know how much the long is worth well the long is made up of ten individual cubes and therefore the long is worth ten let's use this information tell us to compare numbers with base ten blocks let's say for example we had a number with two Long's and two cubes we wanted to compare this to a number with one long and three cubes well one of these blocks really represent one way we can see what this number is quickly by simply counting the base ten blocks starting with the Long's so let's give it a shot in this number we have one long and that's representing ten and another long and that represents ten so we can count by 10 two times let's give it a shot 10 20 now we know we have 20 we can just count on with our other two cubes and represent ones 20 21 22 so I know that these base 10 blocks represent the number 22 well about the number on the right side this side I see 110 already I'm starting to think if there's only 110 in this number it's probably smaller or less than 22 let's count all the base ten blocks just to be sure after ten we can just count on our three cubes ten eleven twelve thirteen so we know that 22 is greater than 13 so we'll draw the comparison symbol with the mouth open towards the bigger number because you will always eat the bigger number let's get started with our worksheet let's read the directions start with the first problem comparing numbers base ten blocks count tens and ones in each pair and compare the numbers check the pairs where the signs of comparison are correct okay we have a nice little reminder up top reminding us about the lungs or worth Tim and the cubes are worth one so let's get s ...
